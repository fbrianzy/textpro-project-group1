# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape Rating Play Store - Mobile Legends: Bang-Bang

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.mobile.legends',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId  \
# 0  f0da301e-17c4-4b70-8221-68104f1d2d0f
# 1  c4a45b0b-d908-4e9d-bf3e-0bc6368b90f4
# 2  db2ef355-254c-4e20-8644-d61d2dfb6dfb
# 3  e04cdb0e-ce3e-49c1-a4bf-4f3e448325a2
# 4  eb498793-a163-48bb-9c03-aa9387509cca
#
#                                             userName  \
# 0                                         Jekki Mius
# 1                                          Hydra Cik
# 2                                    Jonathan Alvaro
# 3                                        Lynvv Store
# 4  Pejuang Rupiah Lupa Bercinta (Story Lupa Berci...
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Dari segi grafiknya cukup bagus ni game, karak...      3            328
# 1  awalnya iya sih gw kasih 5 bintang.... tapi ba...      1           5599
# 2  Game yang kurang baik, developer selalu memiki...      1           1696
# 3  Game nya sih udah bagus tampilan sekarang nya ...      5          10103
# 4  Tadinya bagus, tapi sekarang jadi makin aneh P...      2            123
#
#   reviewCreatedVersion                  at replyContent repliedAt   appVersion
# 0          19.2.11.103 2024-10-02 04:13:07         None       NaT  19.2.11.103
# 1          19.2.11.103 2024-09-30 14:08:19         None       NaT  19.2.11.103
# 2          19.2.11.103 2024-09-27 19:16:20         None       NaT  19.2.11.103
# 3          19.2.11.103 2024-09-20 23:02:35         None       NaT  19.2.11.103
# 4          19.2.11.103 2024-10-04 07:05:36         None       NaT  19.2.11.103

# %%
len(df_busu.index)
# Out:
# 2000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#                                             userName  score  \
# 0                                         Jekki Mius      3
# 1                                          Hydra Cik      1
# 2                                    Jonathan Alvaro      1
# 3                                        Lynvv Store      5
# 4  Pejuang Rupiah Lupa Bercinta (Story Lupa Berci...      2
#
#                    at                                            content
# 0 2024-10-02 04:13:07  Dari segi grafiknya cukup bagus ni game, karak...
# 1 2024-09-30 14:08:19  awalnya iya sih gw kasih 5 bintang.... tapi ba...
# 2 2024-09-27 19:16:20  Game yang kurang baik, developer selalu memiki...
# 3 2024-09-20 23:02:35  Game nya sih udah bagus tampilan sekarang nya ...
# 4 2024-10-04 07:05:36  Tadinya bagus, tapi sekarang jadi makin aneh P...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#             userName  score                  at  \
# 1920   Shaefur Robbi      1 2024-10-06 11:47:20
# 11          ice bear      1 2024-10-06 04:52:08
# 1013    Rahmat FrHlk      1 2024-10-06 02:36:52
# 1791  danial saputra      1 2024-10-05 17:50:06
# 1561          nethaa      2 2024-10-05 17:47:57
#
#                                                 content
# 1920  Gamenya bagus, grafiknya lumayan, tapi tolongl...
# 11    for moonton tolong dong di perbaiki lagi bug f...
# 1013  Game ini jika mau kasih kalah player hp jadi p...
# 1791  Tiap abis update pasti dapet dark system dan k...
# 1561  bagus gamenya cuman gue lose streak dari epik ...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                 content  score
# 1920  Gamenya bagus, grafiknya lumayan, tapi tolongl...      1
# 11    for moonton tolong dong di perbaiki lagi bug f...      1
# 1013  Game ini jika mau kasih kalah player hp jadi p...      1
# 1791  Tiap abis update pasti dapet dark system dan k...      1
# 1561  bagus gamenya cuman gue lose streak dari epik ...      2

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head(50)
# Out:
#                                                 content  score    Label
# 1920  Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 11    for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 1013  Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 1791  Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 1561  bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 66    Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 401   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 1963  Game ini si bagus tapi terlalu banyak dark sis...      3     None
# 1946  saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 90    ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 160   Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 1004  Game nya bagus tapi tolong muntun kasih tim ya...      3     None
# 773   Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 1819  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 845   Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 1714  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 33    Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 1660  Skin² nya ilang di hero² tertentu misalnya arg...      3     None
# 317   Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 34    Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 804   game sampah setiap main di kasih tim drak syst...      1  Negatif
# 1676  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 713   Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
# 31    Ya menurut gw bagus ya game moba 5v5, lebih ba...      3     None
# 1436  Saya sebagai solo player ingin mencapai rank t...      5  Positif
# 1820  Pihak moonton yang paling paling paling terhor...      5  Positif
# 789   tolong yaa, buat moonton... tolong banget!!! i...      5  Positif
# 333   Game nya sih bagus tapi dan oke juga tapi kalo...      4  Positif
# 1538  Jngn download.. buat yg punya darah tinggi, da...      1  Negatif
# 1844  Ini bagus sekali jir permainan sekarang aku kl...      5  Positif
# 727   Game nya dah bagus, tapi kadang suka dapet tim...      5  Positif
# 176   Game sudah sangat bagus dan grafikpun ok tapi ...      3     None
# 658   Bagus tapi kam mobile Legends itu bisa mode of...      4  Positif
# 96    ya sebenarnya bagus bagus aja, cuman terkadang...      3     None
# 660   Dear moonton kenapa sih setiap match pasting n...      1  Negatif
# 1716  Game nya bagus tapi kalo aku main kasih lah ti...      1  Negatif
# 200   saran untuk mlbb kalau bisa di buatkan yg vers...      5  Positif
# 24    sebenernya game nya bagus bagus aja cuman ada ...      3     None
# 1933  Harmfull game !! Becareful , this game is Very...      1  Negatif
# 1983  Habis pembaharuan, ini kok makin parah . D lob...      1  Negatif
# 120   Saya gak tau mau bagaimana lagi,tapi saya akan...      1  Negatif
# 1746  Dark sistem asu, tinggal 1 bintang lgi malah k...      1  Negatif
# 486   Match making yang belum sangat adil. Saat berm...      1  Negatif
# 377   Jaringan bagus lancar tapi kok tiba2 gamenya b...      1  Negatif
# 721   Kenapa habis di update malah crash apk nya moo...      5  Positif
# 118   GAME BURUK, nyesel nya klo udh download, awal²...      1  Negatif
# 1553  Bug sinyal gajelas,setiap main rank tiba"lag b...      5  Positif
# 1715  ML adalah game terburuk bagi gua dan muntun me...      1  Negatif
# 62    Sumpah ni game nambah aneh, karena tadi ulang ...      2  Negatif
# 649   Kepada pihak ML dan penyepong-penyepongnya tol...      3     None

# %%
my_df.to_csv('scrapped_data_mlbb.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/scrapped_data_mlbb.csv')
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 7   Game ini si bagus tapi terlalu banyak dark sis...      3      NaN
# 8   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 9   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 10  Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 11  Game nya bagus tapi tolong muntun kasih tim ya...      3      NaN
# 12  Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 13  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 14  Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 15  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 16  Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 17  Skin² nya ilang di hero² tertentu misalnya arg...      3      NaN
# 18  Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 19  Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 20  game sampah setiap main di kasih tim drak syst...      1  Negatif
# 21  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 22  Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
# 23  Ya menurut gw bagus ya game moba 5v5, lebih ba...      3      NaN
# 24  Saya sebagai solo player ingin mencapai rank t...      5  Positif
# 25  Pihak moonton yang paling paling paling terhor...      5  Positif
# 26  tolong yaa, buat moonton... tolong banget!!! i...      5  Positif
# 27  Game nya sih bagus tapi dan oke juga tapi kalo...      4  Positif
# 28  Jngn download.. buat yg punya darah tinggi, da...      1  Negatif
# 29  Ini bagus sekali jir permainan sekarang aku kl...      5  Positif
# 30  Game nya dah bagus, tapi kadang suka dapet tim...      5  Positif
# 31  Game sudah sangat bagus dan grafikpun ok tapi ...      3      NaN
# 32  Bagus tapi kam mobile Legends itu bisa mode of...      4  Positif
# 33  ya sebenarnya bagus bagus aja, cuman terkadang...      3      NaN
# 34  Dear moonton kenapa sih setiap match pasting n...      1  Negatif
# 35  Game nya bagus tapi kalo aku main kasih lah ti...      1  Negatif
# 36  saran untuk mlbb kalau bisa di buatkan yg vers...      5  Positif
# 37  sebenernya game nya bagus bagus aja cuman ada ...      3      NaN
# 38  Harmfull game !! Becareful , this game is Very...      1  Negatif
# 39  Habis pembaharuan, ini kok makin parah . D lob...      1  Negatif
# 40  Saya gak tau mau bagaimana lagi,tapi saya akan...      1  Negatif
# 41  Dark sistem asu, tinggal 1 bintang lgi malah k...      1  Negatif
# 42  Match making yang belum sangat adil. Saat berm...      1  Negatif
# 43  Jaringan bagus lancar tapi kok tiba2 gamenya b...      1  Negatif
# 44  Kenapa habis di update malah crash apk nya moo...      5  Positif
# 45  GAME BURUK, nyesel nya klo udh download, awal²...      1  Negatif
# 46  Bug sinyal gajelas,setiap main rank tiba"lag b...      5  Positif
# 47  ML adalah game terburuk bagi gua dan muntun me...      1  Negatif
# 48  Sumpah ni game nambah aneh, karena tadi ulang ...      2  Negatif
# 49  Kepada pihak ML dan penyepong-penyepongnya tol...      3      NaN

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2000 non-null   object
#  1   score    2000 non-null   int64
#  2   Label    1789 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 1995    False  False  False
# 1996    False  False  False
# 1997    False  False  False
# 1998    False  False   True
# 1999    False  False  False
#
# [2000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2000.000000
# mean      2.279000
# std       1.560569
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       4.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      211
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 8   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 9   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 10  Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 12  Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 13  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 14  Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 15  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 16  Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 18  Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 19  Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 20  game sampah setiap main di kasih tim drak syst...      1  Negatif
# 21  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 22  Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
# 24  Saya sebagai solo player ingin mencapai rank t...      5  Positif
# 25  Pihak moonton yang paling paling paling terhor...      5  Positif
# 26  tolong yaa, buat moonton... tolong banget!!! i...      5  Positif
# 27  Game nya sih bagus tapi dan oke juga tapi kalo...      4  Positif
# 28  Jngn download.. buat yg punya darah tinggi, da...      1  Negatif
# 29  Ini bagus sekali jir permainan sekarang aku kl...      5  Positif
# 30  Game nya dah bagus, tapi kadang suka dapet tim...      5  Positif
# 32  Bagus tapi kam mobile Legends itu bisa mode of...      4  Positif
# 34  Dear moonton kenapa sih setiap match pasting n...      1  Negatif
# 35  Game nya bagus tapi kalo aku main kasih lah ti...      1  Negatif
# 36  saran untuk mlbb kalau bisa di buatkan yg vers...      5  Positif
# 38  Harmfull game !! Becareful , this game is Very...      1  Negatif
# 39  Habis pembaharuan, ini kok makin parah . D lob...      1  Negatif
# 40  Saya gak tau mau bagaimana lagi,tapi saya akan...      1  Negatif
# 41  Dark sistem asu, tinggal 1 bintang lgi malah k...      1  Negatif
# 42  Match making yang belum sangat adil. Saat berm...      1  Negatif
# 43  Jaringan bagus lancar tapi kok tiba2 gamenya b...      1  Negatif
# 44  Kenapa habis di update malah crash apk nya moo...      5  Positif
# 45  GAME BURUK, nyesel nya klo udh download, awal²...      1  Negatif
# 46  Bug sinyal gajelas,setiap main rank tiba"lag b...      5  Positif
# 47  ML adalah game terburuk bagi gua dan muntun me...      1  Negatif
# 48  Sumpah ni game nambah aneh, karena tadi ulang ...      2  Negatif
# 50  MLBB memang game favorit gamers, tapi saya mau...      5  Positif
# 51  Teruntuk moonton sang developer ML, saya bisa ...      1  Negatif
# 53  Parah sinyal sekarang dan pembagian team tidak...      1  Negatif
# 54  saya ingin event² di permurah dan juga soal in...      5  Positif
# 55  Ini game dulu nya asik gak seperti season seka...      1  Negatif
# 56  Update berkedok downgrade. Sinyal makin ga sta...      1  Negatif
# 57  Moonton assuuuuu, konttoooll, kenapa dikasih d...      1  Negatif
# 58  Semenjak d update sering stak kadang ngelag d ...      1  Negatif

# %%
my_df.to_csv('mlbb_preprocessing.csv', index=False)

# %% [markdown]
# #Text Pre-Processing

# %%
df = pd.read_csv('/content/mlbb_preprocessing.csv')
df.head(50)
# Out:
#                                               content  score    Label
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 7   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 8   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 9   Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 10  Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 11  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 12  Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 13  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 14  Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 15  Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 16  Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 17  game sampah setiap main di kasih tim drak syst...      1  Negatif
# 18  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 19  Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
# 20  Saya sebagai solo player ingin mencapai rank t...      5  Positif
# 21  Pihak moonton yang paling paling paling terhor...      5  Positif
# 22  tolong yaa, buat moonton... tolong banget!!! i...      5  Positif
# 23  Game nya sih bagus tapi dan oke juga tapi kalo...      4  Positif
# 24  Jngn download.. buat yg punya darah tinggi, da...      1  Negatif
# 25  Ini bagus sekali jir permainan sekarang aku kl...      5  Positif
# 26  Game nya dah bagus, tapi kadang suka dapet tim...      5  Positif
# 27  Bagus tapi kam mobile Legends itu bisa mode of...      4  Positif
# 28  Dear moonton kenapa sih setiap match pasting n...      1  Negatif
# 29  Game nya bagus tapi kalo aku main kasih lah ti...      1  Negatif
# 30  saran untuk mlbb kalau bisa di buatkan yg vers...      5  Positif
# 31  Harmfull game !! Becareful , this game is Very...      1  Negatif
# 32  Habis pembaharuan, ini kok makin parah . D lob...      1  Negatif
# 33  Saya gak tau mau bagaimana lagi,tapi saya akan...      1  Negatif
# 34  Dark sistem asu, tinggal 1 bintang lgi malah k...      1  Negatif
# 35  Match making yang belum sangat adil. Saat berm...      1  Negatif
# 36  Jaringan bagus lancar tapi kok tiba2 gamenya b...      1  Negatif
# 37  Kenapa habis di update malah crash apk nya moo...      5  Positif
# 38  GAME BURUK, nyesel nya klo udh download, awal²...      1  Negatif
# 39  Bug sinyal gajelas,setiap main rank tiba"lag b...      5  Positif
# 40  ML adalah game terburuk bagi gua dan muntun me...      1  Negatif
# 41  Sumpah ni game nambah aneh, karena tadi ulang ...      2  Negatif
# 42  MLBB memang game favorit gamers, tapi saya mau...      5  Positif
# 43  Teruntuk moonton sang developer ML, saya bisa ...      1  Negatif
# 44  Parah sinyal sekarang dan pembagian team tidak...      1  Negatif
# 45  saya ingin event² di permurah dan juga soal in...      5  Positif
# 46  Ini game dulu nya asik gak seperti season seka...      1  Negatif
# 47  Update berkedok downgrade. Sinyal makin ga sta...      1  Negatif
# 48  Moonton assuuuuu, konttoooll, kenapa dikasih d...      1  Negatif
# 49  Semenjak d update sering stak kadang ngelag d ...      1  Negatif

# %% [markdown]
# #Case Folding

# %%
import re
def clean_text(df, text_field, new_text_field_name):
  my_df[new_text_field_name] = my_df[text_field].str.lower()
  my_df[new_text_field_name] = my_df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))

  my_df[new_text_field_name] = my_df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
  return my_df

# %%
my_df['text_clean'] = my_df['content'].str.lower()
my_df['text_clean']
data_clean = clean_text(my_df, 'content', 'text_clean')
data_clean.head(10)
# Out:
#                                               content  score    Label  \
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 8   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 9   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 10  Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
#
#                                            text_clean
# 0   gamenya bagus grafiknya lumayan tapi tolonglah...
# 1   for moonton tolong dong di perbaiki lagi bug f...
# 2   game ini jika mau kasih kalah player hp jadi p...
# 3   tiap abis update pasti dapet dark system dan k...
# 4   bagus gamenya cuman gue lose streak dari epik ...
# 5   game apa sih ini cokk cape bgt gua asli buat p...
# 6   hallo moonton ini untuk kesekian kali nya kalo...
# 8   saya ada keluhan sedikit kenapa saya saat main...
# 9   ada bug saat mengganti akun muncul tulisan jar...
# 10  rank tertinggi gwe mitic bisa di bilng udh pah...

# %% [markdown]
# #Stopwords Removal

# %%
import nltk.corpus
nltk.download('stopwords')

from nltk.corpus import stopwords
stop = stopwords.words('indonesian')

data_clean['text_Stopword'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head(50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               content  score    Label  \
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 8   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 9   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 10  Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 12  Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 13  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 14  Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 15  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 16  Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 18  Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 19  Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 20  game sampah setiap main di kasih tim drak syst...      1  Negatif
# 21  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 22  Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
# 24  Saya sebagai solo player ingin mencapai rank t...      5  Positif
# 25  Pihak moonton yang paling paling paling terhor...      5  Positif
# 26  tolong yaa, buat moonton... tolong banget!!! i...      5  Positif
# 27  Game nya sih bagus tapi dan oke juga tapi kalo...      4  Positif
# 28  Jngn download.. buat yg punya darah tinggi, da...      1  Negatif
# 29  Ini bagus sekali jir permainan sekarang aku kl...      5  Positif
# 30  Game nya dah bagus, tapi kadang suka dapet tim...      5  Positif
# 32  Bagus tapi kam mobile Legends itu bisa mode of...      4  Positif
# 34  Dear moonton kenapa sih setiap match pasting n...      1  Negatif
# 35  Game nya bagus tapi kalo aku main kasih lah ti...      1  Negatif
# 36  saran untuk mlbb kalau bisa di buatkan yg vers...      5  Positif
# 38  Harmfull game !! Becareful , this game is Very...      1  Negatif
# 39  Habis pembaharuan, ini kok makin parah . D lob...      1  Negatif
# 40  Saya gak tau mau bagaimana lagi,tapi saya akan...      1  Negatif
# 41  Dark sistem asu, tinggal 1 bintang lgi malah k...      1  Negatif
# 42  Match making yang belum sangat adil. Saat berm...      1  Negatif
# 43  Jaringan bagus lancar tapi kok tiba2 gamenya b...      1  Negatif
# 44  Kenapa habis di update malah crash apk nya moo...      5  Positif
# 45  GAME BURUK, nyesel nya klo udh download, awal²...      1  Negatif
# 46  Bug sinyal gajelas,setiap main rank tiba"lag b...      5  Positif
# 47  ML adalah game terburuk bagi gua dan muntun me...      1  Negatif
# 48  Sumpah ni game nambah aneh, karena tadi ulang ...      2  Negatif
# 50  MLBB memang game favorit gamers, tapi saya mau...      5  Positif
# 51  Teruntuk moonton sang developer ML, saya bisa ...      1  Negatif
# 53  Parah sinyal sekarang dan pembagian team tidak...      1  Negatif
# 54  saya ingin event² di permurah dan juga soal in...      5  Positif
# 55  Ini game dulu nya asik gak seperti season seka...      1  Negatif
# 56  Update berkedok downgrade. Sinyal makin ga sta...      1  Negatif
# 57  Moonton assuuuuu, konttoooll, kenapa dikasih d...      1  Negatif
# 58  Semenjak d update sering stak kadang ngelag d ...      1  Negatif
#
#                                            text_clean  \
# 0   gamenya bagus grafiknya lumayan tapi tolonglah...
# 1   for moonton tolong dong di perbaiki lagi bug f...
# 2   game ini jika mau kasih kalah player hp jadi p...
# 3   tiap abis update pasti dapet dark system dan k...
# 4   bagus gamenya cuman gue lose streak dari epik ...
# 5   game apa sih ini cokk cape bgt gua asli buat p...
# 6   hallo moonton ini untuk kesekian kali nya kalo...
# 8   saya ada keluhan sedikit kenapa saya saat main...
# 9   ada bug saat mengganti akun muncul tulisan jar...
# 10  rank tertinggi gwe mitic bisa di bilng udh pah...
# 12  permainan di kasi musuh yg jago yg sesuai lah ...
# 13  jujur lah saya dpt tim yang sangat amat buruk ...
# 14  untuk kedepannya mohon perbaiki masalah sinyal...
# 15  sudah sekian lama game ini masih saja ngeleg s...
# 16  game nya sudah bagus dari tampilan grafik dan ...
# 18  game nya menyenangkan cuma yang belum kecandua...
# 19  mobile legends untuk pengembang kalau nggak be...
# 20  game sampah setiap main di kasih tim drak syst...
# 21  masa gue donlot data ga bisa jalan jalan sih b...
# 22  matchmakingnya tolong diperbaiki perbedaan ran...
# 24  saya sebagai solo player ingin mencapai rank t...
# 25  pihak moonton yang paling paling paling terhor...
# 26  tolong yaa buat moonton tolong banget ini yg m...
# 27  game nya sih bagus tapi dan oke juga tapi kalo...
# 28  jngn download buat yg punya darah tinggi darip...
# 29  ini bagus sekali jir permainan sekarang aku kl...
# 30  game nya dah bagus tapi kadang suka dapet tim ...
# 32  bagus tapi kam mobile legends itu bisa mode of...
# 34  dear moonton kenapa sih setiap match pasting n...
# 35  game nya bagus tapi kalo aku main kasih lah ti...
# 36  saran untuk mlbb kalau bisa di buatkan yg vers...
# 38  harmfull game  becareful  this game is very da...
# 39  habis pembaharuan ini kok makin parah  d loby ...
# 40  saya gak tau mau bagaimana lagitapi saya akan ...
# 41  dark sistem asu tinggal  bintang lgi malah kal...
# 42  match making yang belum sangat adil saat berma...
# 43  jaringan bagus lancar tapi kok tiba gamenya be...
# 44  kenapa habis di update malah crash apk nya moo...
# 45  game buruk nyesel nya klo udh download awal am...
# 46  bug sinyal gajelassetiap main rank tibalag bik...
# 47  ml adalah game terburuk bagi gua dan muntun me...
# 48  sumpah ni game nambah aneh karena tadi ulang t...
# 50  mlbb memang game favorit gamers tapi saya mau ...
# 51  teruntuk moonton sang developer ml saya bisa m...
# 53  parah sinyal sekarang dan pembagian team tidak...
# 54  saya ingin event di permurah dan juga soal in ...
# 55  ini game dulu nya asik gak seperti season seka...
# 56  update berkedok downgrade sinyal makin ga stab...
# 57  moonton assuuuuu konttoooll kenapa dikasih dar...
# 58  semenjak d update sering stak kadang ngelag d ...
#
#                                         text_Stopword
# 0   gamenya bagus grafiknya lumayan tolonglah kasi...
# 1   for moonton tolong perbaiki bug freeze kadang ...
# 2   game kasih kalah player hp panas kasih player ...
# 3   abis update dapet dark system keselnya player ...
# 4   bagus gamenya cuman gue lose streak epik binta...
# 5   game sih cokk cape bgt gua asli player solo gi...
# 6   hallo moonton kesekian kali nya kalo match dap...
# 8   keluhan main rank menemukan musuh pangkatnya u...
# 9   bug mengganti akun muncul tulisan jaringan sta...
# 10  rank tertinggi gwe mitic bilng udh paham itemr...
# 12  permainan kasi musuh yg jago yg sesuai gua kal...
# 13  jujur dpt tim buruk kadang anggota tim feedeer...
# 14  kedepannya mohon perbaiki sinyaljaringan bange...
# 15  sekian game ngeleg bertempur jgn gituh nonton ...
# 16  game nya bagus tampilan grafik hero nya mantap...
# 18  game nya menyenangkan kecanduan deh emosi mont...
# 19  mobile legends pengembang nggak becus mengelol...
# 20  game sampah main kasih tim drak system cape gu...
# 21  gue donlot data ga jalan jalan sih beebrapa ud...
# 22  matchmakingnya tolong diperbaiki perbedaan ran...
# 24  solo player mencapai rank tertinggi mlbb gagal...
# 25  moonton terhormat mohon perbaiki servernya ter...
# 26  tolong yaa moonton tolong banget yg main pelos...
# 27  game nya sih bagus oke kalo mulaistart game ja...
# 28  jngn download yg darah tekanan darah keseimban...
# 29  bagus jir permainan kls main sekolah udh main ...
# 30  game nya dah bagus kadang suka dapet tim aneh ...
# 32  bagus kam mobile legends mode offlain tolong o...
# 34  dear moonton sih match pasting ngeleg menit tu...
# 35  game nya bagus kalo main kasih tim bener main ...
# 36  saran mlbb buatkan yg versi lite peruntukan hp...
# 38  harmfull game becareful this game is very dang...
# 39  habis pembaharuan parah d loby signal ijo seka...
# 40  gak tau lagitapi menghapus game inikarena mobi...
# 41  dark sistem asu tinggal bintang lgi kalah udah...
# 42  match making adil bermain solo player membeban...
# 43  jaringan bagus lancar gamenya berhenti pingin ...
# 44  habis update crash apk nya moonton terpaksa do...
# 45  game buruk nyesel nya klo udh download aman dp...
# 46  bug sinyal gajelassetiap main rank tibalag bik...
# 47  ml game terburuk gua muntun merancang rencana ...
# 48  sumpah ni game nambah aneh ulang trus yg emang...
# 50  mlbb game favorit gamers sarannya moonton akun...
# 51  teruntuk moonton sang developer ml game buruk ...
# 53  parah sinyal pembagian team seimbang burukbuat...
# 54  event permurah in game penyesuaian mach rank b...
# 55  game nya asik gak season kaya ta gua sbgai pem...
# 56  update berkedok downgrade sinyal ga stabil ani...
# 57  moonton assuuuuu konttoooll dikasih dark siste...
# 58  semenjak d update stak kadang ngelag d permain...

# %% [markdown]
# #Tokenizing

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_Stopword'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                              content  score    Label  \
# 0  Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1  for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2  Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3  Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4  bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
#
#                                           text_clean  \
# 0  gamenya bagus grafiknya lumayan tapi tolonglah...
# 1  for moonton tolong dong di perbaiki lagi bug f...
# 2  game ini jika mau kasih kalah player hp jadi p...
# 3  tiap abis update pasti dapet dark system dan k...
# 4  bagus gamenya cuman gue lose streak dari epik ...
#
#                                        text_Stopword  \
# 0  gamenya bagus grafiknya lumayan tolonglah kasi...
# 1  for moonton tolong perbaiki bug freeze kadang ...
# 2  game kasih kalah player hp panas kasih player ...
# 3  abis update dapet dark system keselnya player ...
# 4  bagus gamenya cuman gue lose streak epik binta...
#
#                                          text_tokens
# 0  [gamenya, bagus, grafiknya, lumayan, tolonglah...
# 1  [for, moonton, tolong, perbaiki, bug, freeze, ...
# 2  [game, kasih, kalah, player, hp, panas, kasih,...
# 3  [abis, update, dapet, dark, system, keselnya, ...
# 4  [bagus, gamenya, cuman, gue, lose, streak, epi...

# %% [markdown]
# #Stemming

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
def stemmed_wrapper(term):
  return stemmer.stem(term)

term_dict = {}
hitung = 0

for document in data_clean['text_tokens']:
  for term in document:
    if term not in term_dict:
      term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
  term_dict[term] = stemmed_wrapper(term)
  hitung += 1
  print(hitung, ":", term, ":", term_dict[term])

print(term_dict)
print("------------------------")

def get_stemmed_term(document):
  return [term_dict[term] for term in document]

data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2144 : turret : turret
# 2145 : ja : ja
# 2146 : hncur : hncur
# 2147 : satupun : satu
# 2148 : hebatnya : hebat
# 2149 : bru : bru
# 2150 : mnang : mnang
# 2151 : kdang : kdang
# 2152 : klah : klah
# 2153 : belasan : bas
# 2154 : terbesar : besar
# 2155 : yabg : yabg
# 2156 : didasarkan : dasar
# 2157 : memiliki : milik
# 2158 : menyebabkan : sebab
# 2159 : menurun : turun
# 2160 : akibat : akibat
# 2161 : belah : belah
# 2162 : temuingame : temuingame
# 2163 : anehstiap : anehstiap
# 2164 : pict : pict
# 2165 : lagemblem : lagemblem
# 2166 : gnti : gnti
# 2167 : sndirigame : sndirigame
# 2168 : sampahgame : sampahgame
# 2169 : burikgame : burikgame
# 2170 : adiljdi : adiljdi
# 2171 : ginimusuh : ginimusuh
# 2172 : begotim : begotim
# 2173 : montonmusuh : montonmusuh
# 2174 : jagotim : jagotim
# 2175 : begotrs : begotrs
# 2176 : pisahkan : pisah
# 2177 : membedakannya : beda
# 2178 : sayasetara : sayasetara
# 2179 : berkembang : kembang
# 2180 : knapa : knapa
# 2181 : tenggelam : tenggelam
# 2182 : mlah : mlah
# 2183 : drastis : drastis
# 2184 : muak : muak
# 2185 : teamkarena : teamkarena
# 2186 : ketemuseteam : ketemuseteam
# 2187 : mampus : mampus
# 2188 : sajasaat : sajasaat
# 2189 : winstrike : winstrike
# 2190 : darksystemsampe : darksystemsampe
# 2191 : ranktolongggggg : ranktolongggggg
# 2192 : perbaikijika : perbaikijika
# 2193 : ituya : ituya
# 2194 : sebelahmemang : sebelahmemang
# 2195 : membagikan : bagi
# 2196 : gratistapi : gratistapi
# 2197 : boongplayer : boongplayer
# 2198 : gratislangsung : gratislangsung
# 2199 : seteam : seteam
# 2200 : u : u
# 2201 : ngeluh : ngeluh
# 2202 : kakurangan : kakurangan
# 2203 : lh : lh
# 2204 : bag : bag
# 2205 : players : players
# 2206 : mles : mles
# 2207 : modemetode : modemetode
# 2208 : mendeteksi : deteksi
# 2209 : curang : curang
# 2210 : sepertimenggunakan : sepertimenggunakan
# 2211 : wangi : wangi
# 2212 : jasa : jasa
# 2213 : joki : joki
# 2214 : sebagainyaagar : sebagainyaagar
# 2215 : meningkatkan : tingkat
# 2216 : ringan : ringan
# 2217 : genshin : genshin
# 2218 : ffjadi : ffjadi
# 2219 : sistemlawan : sistemlawan
# 2220 : kitalawan : kitalawan
# 2221 : tinggiselalu : tinggiselalu
# 2222 : ginijadi : ginijadi
# 2223 : inimohon : inimohon
# 2224 : playermlbb : playermlbb
# 2225 : bersinar : sinar
# 2226 : sendat : sendat
# 2227 : restad : restad
# 2228 : tingkatan : tingkat
# 2229 : ngeleq : ngeleq
# 2230 : terbaru : baru
# 2231 : smartphone : smartphone
# 2232 : chip : chip
# 2233 : snapdragon : snapdragon
# 2234 : c : c
# 2235 : bawaan : bawa
# 2236 : cs : cs
# 2237 : silvanna : silvanna
# 2238 : mereport : mereport
# 2239 : feeding : feeding
# 2240 : melanggar : langgar
# 2241 : peraturan : atur
# 2242 : manusia : manusia
# 2243 : bangsad : bangsad
# 2244 : entar : entar
# 2245 : pencocokan : cocok
# 2246 : berebut : rebut
# 2247 : gamplay : gamplay
# 2248 : acak : acak
# 2249 : seombang : seombang
# 2250 : dikurangin : rangin
# 2251 : ngerasain : ngerasain
# 2252 : montodkontol : montodkontol
# 2253 : simulasi : simulasi
# 2254 : berskill : berskill
# 2255 : cacat : cacat
# 2256 : terkategori : kategori
# 2257 : sekalianbiar : sekalianbiar
# 2258 : naiktolong : naiktolong
# 2259 : patroliyg : patroliyg
# 2260 : dibuang : buang
# 2261 : lahitu : lahitu
# 2262 : virus : virus
# 2263 : menganggu : menganggu
# 2264 : bermaincapek : bermaincapek
# 2265 : moontonlu : moontonlu
# 2266 : gagw : gagw
# 2267 : draftpick : draftpick
# 2268 : diatasnya : atas
# 2269 : kayu : kayu
# 2270 : larangan : larang
# 2271 : device : device
# 2272 : email : email
# 2273 : verifnya : verifnya
# 2274 : nyoba : nyoba
# 2275 : bangga : bangga
# 2276 : unik : unik
# 2277 : google : google
# 2278 : papa : papa
# 2279 : mempersiasiterima : mempersiasiterima
# 2280 : badmood : badmood
# 2281 : tertolong : tolong
# 2282 : gabut : gabut
# 2283 : pokok : pokok
# 2284 : lupa : lupa
# 2285 : skilnya : skilnya
# 2286 : bye : bye
# 2287 : salam : salam
# 2288 : toleransi : toleransi
# 2289 : thanks : thanks
# 2290 : okelah : oke
# 2291 : yt : yt
# 2292 : aktifitas : aktifitas
# 2293 : hadiah : hadiah
# 2294 : hadianya : hadianya
# 2295 : mene : mene
# 2296 : mani : mani
# 2297 : ff : ff
# 2298 : kesendirian : sendiri
# 2299 : terbaikku : baik
# 2300 : berteman : teman
# 2301 : pintu : pintu
# 2302 : melese : melese
# 2303 : padaku : pada
# 2304 : gantiganti : gantiganti
# 2305 : baju : baju
# 2306 : gorengan : goreng
# 2307 : nelpon : nelpon
# 2308 : notif : notif
# 2309 : lokasinya : lokasi
# 2310 : apaapa : apaapa
# 2311 : kit : kit
# 2312 : ydan : ydan
# 2313 : spin : spin
# 2314 : kepakesaya : kepakesaya
# 2315 : b : b
# 2316 : dulusaya : dulusaya
# 2317 : jadinyaama : jadinyaama
# 2318 : kondisi : kondisi
# 2319 : fps : fps
# 2320 : ngerank : ngerank
# 2321 : teks : teks
# 2322 : lobbyin : lobbyin
# 2323 : kecuali : kecuali
# 2324 : kebanyak : banyak
# 2325 : bocahhaaaa : bocahhaaaa
# 2326 : knpa : knpa
# 2327 : ndak : ndak
# 2328 : masukgue : masukgue
# 2329 : dc : dc
# 2330 : assuada : assuada
# 2331 : slalu : slalu
# 2332 : lolkenapa : lolkenapa
# 2333 : jaringanjaringan : jaringanjaringan
# 2334 : target : target
# 2335 : market : market
# 2336 : sayahanya : sayahanya
# 2337 : penolakan : tolak
# 2338 : gambar : gambar
# 2339 : memadai : pada
# 2340 : efeknya : efek
# 2341 : sangatsangat : sangatsangat
# 2342 : feeder : feeder
# 2343 : dialognya : dialog
# 2344 : dialog : dialog
# 2345 : aslinya : asli
# 2346 : penyeimbang : imbang
# 2347 : mendptkan : mendptkan
# 2348 : ramahmudah : ramahmudah
# 2349 : menenangkan : tenang
# 2350 : unsital : unsital
# 2351 : berpengaruh : pengaruh
# 2352 : elden : elden
# 2353 : ring : ring
# 2354 : devoleper : devoleper
# 2355 : iklan : iklan
# 2356 : nyh : nyh
# 2357 : kmi : kmi
# 2358 : keganggu : ganggu
# 2359 : bangtttttapi : bangtttttapi
# 2360 : ilangin : ilangin
# 2361 : beres : beres
# 2362 : draks : draks
# 2363 : anehdi : anehdi
# 2364 : tibangelek : tibangelek
# 2365 : anti : anti
# 2366 : teguran : tegur
# 2367 : rankpenting : rankpenting
# 2368 : lainterutama : lainterutama
# 2369 : baiklah : baik
# 2370 : membaca : baca
# 2371 : mnnton : mnnton
# 2372 : bangs : bangs
# 2373 : hey : hey
# 2374 : meng : meng
# 2375 : hubungkan : hubung
# 2376 : to : to
# 2377 : kill : kill
# 2378 : kritik : kritik
# 2379 : v : v
# 2380 : mengoptimalkan : optimal
# 2381 : th : th
# 2382 : larut : larut
# 2383 : semangkin : semangkin
# 2384 : pola : pola
# 2385 : menjengkelkan : jengkel
# 2386 : selanjut : lanjut
# 2387 : boot : boot
# 2388 : takjadi : takjadi
# 2389 : membagoong : membagoong
# 2390 : turuning : turuning
# 2391 : bintangnya : bintang
# 2392 : pandai : pandai
# 2393 : time : time
# 2394 : faigh : faigh
# 2395 : meraih : raih
# 2396 : pemberian : beri
# 2397 : dicerna : cerna
# 2398 : setingan : ting
# 2399 : kota : kota
# 2400 : ponsel : ponsel
# 2401 : mumpuni : mumpuni
# 2402 : telak : telak
# 2403 : issue : issue
# 2404 : no : no
# 2405 : tolongg : tolongg
# 2406 : rumit : rumit
# 2407 : akunku : akun
# 2408 : save : save
# 2409 : terfokuskan : fokus
# 2410 : daridulu : daridulu
# 2411 : rekomen : rekomen
# 2412 : abiskerja : abiskerja
# 2413 : emng : emng
# 2414 : ketempelan : tempel
# 2415 : artefak : artefak
# 2416 : def : def
# 2417 : digenshin : digenshin
# 2418 : diamond : diamond
# 2419 : e : e
# 2420 : mo : mo
# 2421 : kutukan : kutu
# 2422 : inimaka : inimaka
# 2423 : matchny : matchny
# 2424 : muluuu : muluuu
# 2425 : jan : jan
# 2426 : gamau : gamau
# 2427 : wifinya : wifinya
# 2428 : benarkan : benar
# 2429 : resource : resource
# 2430 : nabrak : nabrak
# 2431 : monoton : monoton
# 2432 : wl : wl
# 2433 : dikendalikan : kendali
# 2434 : terlapor : lapor
# 2435 : ngejump : ngejump
# 2436 : macthing : macthing
# 2437 : benturan : bentur
# 2438 : lanedan : lanedan
# 2439 : biarkan : biar
# 2440 : anggap : anggap
# 2441 : menjatuhkan : jatuh
# 2442 : seenak : enak
# 2443 : royal : royal
# 2444 : loyal : loyal
# 2445 : tq : tq
# 2446 : miliki : milik
# 2447 : ultra : ultra
# 2448 : rilis : rilis
# 2449 : datanya : data
# 2450 : geme : geme
# 2451 : menyukainya : suka
# 2452 : hebat : hebat
# 2453 : tugas : tugas
# 2454 : roame : roame
# 2455 : tenk : tenk
# 2456 : tebal : tebal
# 2457 : belakangnya : belakang
# 2458 : mengalah : kalah
# 2459 : bagusssss : bagusssss
# 2460 : gatau : gatau
# 2461 : mendengarkan : dengar
# 2462 : membacanya : baca
# 2463 : mengeluarkan : keluar
# 2464 : turunkan : turun
# 2465 : angka : angka
# 2466 : diatas : atas
# 2467 : jagojago : jagojago
# 2468 : marahpertandinganya : marahpertandinganya
# 2469 : tersampah : sampah
# 2470 : carry : carry
# 2471 : ehh : ehh
# 2472 : emg : emg
# 2473 : tot : tot
# 2474 : playernya : playernya
# 2475 : kya : kya
# 2476 : gunaditambah : gunaditambah
# 2477 : big : big
# 2478 : selamat : selamat
# 2479 : tanda : tanda
# 2480 : wk : wk
# 2481 : thn : thn
# 2482 : feedback : feedback
# 2483 : menguntungkan : untung
# 2484 : starswar : starswar
# 2485 : kntl : kntl
# 2486 : op : op
# 2487 : dibales : dibales
# 2488 : gimna : gimna
# 2489 : ancur : ancur
# 2490 : menghambat : hambat
# 2491 : kemajuan : maju
# 2492 : pertumbuhan : tumbuh
# 2493 : ceritanya : cerita
# 2494 : pertengahan : tengah
# 2495 : force : force
# 2496 : menyambung : sambung
# 2497 : kedepanya : depa
# 2498 : tahan : tahan
# 2499 : nguntungin : nguntungin
# 2500 : jidat : jidat
# 2501 : literasimasa : literasimasa
# 2502 : apasih : apasih
# 2503 : maunya : mau
# 2504 : udahngasih : udahngasih
# 2505 : ngasal : ngasal
# 2506 : ngasaan : ngasaan
# 2507 : etim : etim
# 2508 : develop : develop
# 2509 : tema : tema
# 2510 : futuristik : futuristik
# 2511 : ungu : ungu
# 2512 : liatnya : liat
# 2513 : gasuka : gasuka
# 2514 : fati : fati
# 2515 : tawar : tawar
# 2516 : ditawar : tawar
# 2517 : monnton : monnton
# 2518 : los : los
# 2519 : abgus : abgus
# 2520 : bis : bis
# 2521 : alog : alog
# 2522 : kuranglalu : kuranglalu
# 2523 : nggk : nggk
# 2524 : ngadain : ngadain
# 2525 : penduduk : duduk
# 2526 : kendalanya : kendala
# 2527 : matchmakingnyamasa : matchmakingnyamasa
# 2528 : dihitung : hitung
# 2529 : afkgara : afkgara
# 2530 : dalem : dalem
# 2531 : gelag : gelag
# 2532 : lansung : lansung
# 2533 : galamin : galamin
# 2534 : optimalisasi : optimalisasi
# 2535 : have : have
# 2536 : curhatan : curhatan
# 2537 : dikwalitas : dikwalitas
# 2538 : gambarnya : gambar
# 2539 : mendadak : dadak
# 2540 : laghilangdapet : laghilangdapet
# 2541 : damagenya : damagenya
# 2542 : betulkan : betul
# 2543 : ultranya : ultra
# 2544 : ngejek : ngejek
# 2545 : turunnya : turun
# 2546 : masalahmasalahnya : masalahmasalahnya
# 2547 : devolover : devolover
# 2548 : seting : ting
# 2549 : berpikir : pikir
# 2550 : strategi : strategi
# 2551 : offlinenya : offlinenya
# 2552 : item : item
# 2553 : onlinenya : onlinenya
# 2554 : exe : exe
# 2555 : clock : clock
# 2556 : destny : destny
# 2557 : winter : winter
# 2558 : blood : blood
# 2559 : report : report
# 2560 : dipertegas : tegas
# 2561 : pertegas : tegas
# 2562 : jatuhkan : jatuh
# 2563 : bagusbagus : bagusbagus
# 2564 : invalid : invalid
# 2565 : tempatkudan : tempatkudan
# 2566 : gametolonglah : gametolonglah
# 2567 : gmna : gmna
# 2568 : chase : chase
# 2569 : dimna : dimna
# 2570 : mengumpulkan : kumpul
# 2571 : refresh : refresh
# 2572 : keburu : keburu
# 2573 : hbis : hbis
# 2574 : koin : koin
# 2575 : tabung : tabung
# 2576 : naikkan : naik
# 2577 : comander : comander
# 2578 : butuhkan : butuh
# 2579 : dicampur : campur
# 2580 : matic : matic
# 2581 : lahhh : lahhh
# 2582 : dongo : dongo
# 2583 : peminatnya : minat
# 2584 : ditawarkan : tawar
# 2585 : diper : per
# 2586 : memory : memory
# 2587 : ukuran : ukur
# 2588 : tembus : tembus
# 2589 : kotakkotak : kotakkotak
# 2590 : mengulur : ulur
# 2591 : wee : wee
# 2592 : yaang : yaang
# 2593 : dibagus : bagus
# 2594 : bagusin : bagusin
# 2595 : nerf : nerf
# 2596 : perketat : ketat
# 2597 : cepet : cepet
# 2598 : gas : gas
# 2599 : sisitem : sisitem
# 2600 : kebanyakn : kebanyakn
# 2601 : diambil : ambil
# 2602 : projek : projek
# 2603 : istilahnya : istilah
# 2604 : teknologi : teknologi
# 2605 : konsep : konsep
# 2606 : mengalahi : kalah
# 2607 : skins : skins
# 2608 : mimin : mimin
# 2609 : sebelahhonor : sebelahhonor
# 2610 : minn : minn
# 2611 : rabk : rabk
# 2612 : tingg : tingg
# 2613 : basick : basick
# 2614 : phoveus : phoveus
# 2615 : special : special
# 2616 : mulumoonton : mulumoonton
# 2617 : prosetiap : prosetiap
# 2618 : macht : macht
# 2619 : matcmachingnya : matcmachingnya
# 2620 : teamnya : teamnya
# 2621 : jumping : jumping
# 2622 : legleg : legleg
# 2623 : dana : dana
# 2624 : montonnya : montonnya
# 2625 : rankn : rankn
# 2626 : tertinggal : tinggal
# 2627 : lamaan : lama
# 2628 : trusss : trusss
# 2629 : komen : komen
# 2630 : beginiiiiiiii : beginiiiiiiii
# 2631 : sori : sori
# 2632 : krna : krna
# 2633 : glori : glori
# 2634 : start : start
# 2635 : mrka : mrka
# 2636 : roamer : roamer
# 2637 : bwat : bwat
# 2638 : tb : tb
# 2639 : mmnya : mmnya
# 2640 : kyak : kyak
# 2641 : clasic : clasic
# 2642 : kadangmaka : kadangmaka
# 2643 : kubalas : balas
# 2644 : gass : gass
# 2645 : fanny : fanny
# 2646 : gastabil : gastabil
# 2647 : prmainan : prmainan
# 2648 : lnjut : lnjut
# 2649 : crediit : crediit
# 2650 : jd : jd
# 2651 : diurus : urus
# 2652 : kgk : kgk
# 2653 : skinmonton : skinmonton
# 2654 : kontolll : kontolll
# 2655 : anjg : anjg
# 2656 : ngntd : ngntd
# 2657 : perhitungan : hitung
# 2658 : lifesteal : lifesteal
# 2659 : lategame : lategame
# 2660 : disamakan : sama
# 2661 : oasis : oasis
# 2662 : yin : yin
# 2663 : keluarin : keluarin
# 2664 : ulti : ulti
# 2665 : cancel : cancel
# 2666 : garis : garis
# 2667 : diggie : diggie
# 2668 : segaris : segar
# 2669 : review : review
# 2670 : patern : patern
# 2671 : berdasarkan : dasar
# 2672 : winrate : winrate
# 2673 : dibkin : dibkin
# 2674 : drop : drop
# 2675 : isinya : isi
# 2676 : fedeer : fedeer
# 2677 : setiapnsetelah : setiapnsetelah
# 2678 : darft : darft
# 2679 : hitungan : hitung
# 2680 : freezz : freezz
# 2681 : solusinya : solusi
# 2682 : kubcoba : kubcoba
# 2683 : all : all
# 2684 : kebijakannya : bijak
# 2685 : rilod : rilod
# 2686 : diusahakan : usaha
# 2687 : hediah : hediah
# 2688 : perbaikisaya : perbaikisaya
# 2689 : ditingkatkan : tingkat
# 2690 : kedepannyadan : kedepannyadan
# 2691 : suyou : suyou
# 2692 : rendahin : rendahin
# 2693 : gampangmakasihuntuk : gampangmakasihuntuk
# 2694 : mole : mole
# 2695 : turuni : turun
# 2696 : bermasaalah : bermasaalah
# 2697 : marchmaking : marchmaking
# 2698 : merata : rata
# 2699 : old : old
# 2700 : mencari : cari
# 2701 : lingkungan : lingkung
# 2702 : sportif : sportif
# 2703 : perbandingan : banding
# 2704 : pangkat : pangkat
# 2705 : dikeluarkan : keluar
# 2706 : surat : surat
# 2707 : terbuka : buka
# 2708 : diilangin : diilangin
# 2709 : amazing : amazing
# 2710 : faham : faham
# 2711 : jagan : jagan
# 2712 : soalnny : soalnny
# 2713 : laaahh : laaahh
# 2714 : matchmakingnyaa : matchmakingnyaa
# 2715 : dicariin : dicariin
# 2716 : lawantim : lawantim
# 2717 : sepadann : sepadann
# 2718 : statistiktier : statistiktier
# 2719 : masaiya : masaiya
# 2720 : diatasinskin : diatasinskin
# 2721 : butuhnya : butuh
# 2722 : sistemnyaa : sistemnyaa
# 2723 : diperbaikin : diperbaikin
# 2724 : eventevent : eventevent
# 2725 : lainlaindark : lainlaindark
# 2726 : menonaktifkan : nonaktif
# 2727 : aktifkan : aktif
# 2728 : open : open
# 2729 : jauhmic : jauhmic
# 2730 : digunakanmau : digunakanmau
# 2731 : dilayar : layar
# 2732 : tunggu : tunggu
# 2733 : lagisaya : lagisaya
# 2734 : aktfkan : aktfkan
# 2735 : mictolong : mictolong
# 2736 : bosku : bos
# 2737 : boss : boss
# 2738 : restart : restart
# 2739 : low : low
# 2740 : mainsedangkan : mainsedangkan
# 2741 : kemarinkadang : kemarinkadang
# 2742 : nyakalo : nyakalo
# 2743 : mulukalo : mulukalo
# 2744 : simple : simple
# 2745 : hhahahaha : hhahahaha
# 2746 : sejago : jago
# 2747 : sebagus : bagus
# 2748 : dkt : dkt
# 2749 : heheh : heheh
# 2750 : moontonini : moontonini
# 2751 : moontonbug : moontonbug
# 2752 : framedrop : framedrop
# 2753 : moontonpadahal : moontonpadahal
# 2754 : infinix : infinix
# 2755 : gt : gt
# 2756 : moontongamingdan : moontongamingdan
# 2757 : moontonkalo : moontonkalo
# 2758 : ajaa : ajaa
# 2759 : framedroptolong : framedroptolong
# 2760 : jugakalau : jugakalau
# 2761 : kesalahan : salah
# 2762 : jugasaya : jugasaya
# 2763 : batleroyal : batleroyal
# 2764 : ajatolong : ajatolong
# 2765 : nyasekian : nyasekian
# 2766 : blgnya : blgnya
# 2767 : keliatan : liat
# 2768 : salma : salma
# 2769 : kuldown : kuldown
# 2770 : ngabisin : ngabisin
# 2771 : developersaya : developersaya
# 2772 : sendirisolo : sendirisolo
# 2773 : developersetelah : developersetelah
# 2774 : mytikkok : mytikkok
# 2775 : bisadan : bisadan
# 2776 : berpesan : pesan
# 2777 : pesankasih : pesankasih
# 2778 : menyusuh : susuh
# 2779 : respont : respont
# 2780 : pkai : pkai
# 2781 : ntah : ntah
# 2782 : pnjoki : pnjoki
# 2783 : ditindak : tindak
# 2784 : reting : reting
# 2785 : teruskan : terus
# 2786 : bekutidak : bekutidak
# 2787 : digerakan : gera
# 2788 : arah : arah
# 2789 : bergeraknya : gerak
# 2790 : dinyatakan : nyata
# 2791 : perbaikan : baik
# 2792 : mengarah : arah
# 2793 : gamebuang : gamebuang
# 2794 : njirsusah : njirsusah
# 2795 : nyari : nyari
# 2796 : home : home
# 2797 : bagushijau : bagushijau
# 2798 : perbanyak : banyak
# 2799 : perbaikinlagi : perbaikinlagi
# 2800 : jaringanyaa : jaringanyaa
# 2801 : tanggapanya : tanggapanya
# 2802 : jaringanya : jaringanya
# 2803 : seluler : seluler
# 2804 : dimohon : mohon
# 2805 : untk : untk
# 2806 : menangis : menang
# 2807 : n : n
# 2808 : iri : iri
# 2809 : tersingkir : singkir
# 2810 : benci : benci
# 2811 : sampha : sampha
# 2812 : bagiku : bagi
# 2813 : mengasih : asih
# 2814 : venom : venom
# 2815 : saber : saber
# 2816 : mengincar : incar
# 2817 : takot : takot
# 2818 : nyingkirin : nyingkirin
# 2819 : alasannya : alas
# 2820 : ngefreze : ngefreze
# 2821 : baned : baned
# 2822 : jangn : jangn
# 2823 : downlod : downlod
# 2824 : mayan : mayan
# 2825 : canda : canda
# 2826 : penyakit : sakit
# 2827 : starlight : starlight
# 2828 : bnyk : bnyk
# 2829 : ruang : ruang
# 2830 : tulisannya : tulis
# 2831 : silahkan : silah
# 2832 : ytb : ytb
# 2833 : tanggung : tanggung
# 2834 : pin : pin
# 2835 : tanggal : tanggal
# 2836 : september : september
# 2837 : gelap : gelap
# 2838 : dengeran : dengeran
# 2839 : sound : sound
# 2840 : musik : musik
# 2841 : mw : mw
# 2842 : minatin : minatin
# 2843 : tok : tok
# 2844 : kn : kn
# 2845 : jualtolong : jualtolong
# 2846 : dipindahkan : pindah
# 2847 : sensitif : sensitif
# 2848 : bulat : bulat
# 2849 : nl : nl
# 2850 : belajar : ajar
# 2851 : nengkasih : nengkasih
# 2852 : mage : mage
# 2853 : lunox : lunox
# 2854 : revamp : revamp
# 2855 : ubah : ubah
# 2856 : dipakaimeta : dipakaimeta
# 2857 : utk : utk
# 2858 : ranknya : ranknya
# 2859 : cheater : cheater
# 2860 : dewa : dewa
# 2861 : case : case
# 2862 : mengakibatkan : akibat
# 2863 : berjalanlag : berjalanlag
# 2864 : ditanggapi : tanggap
# 2865 : pengembangan : kembang
# 2866 : montoontolong : montoontolong
# 2867 : menyinggung : singgung
# 2868 : perasaan : asa
# 2869 : pointanpa : pointanpa
# 2870 : alami : alami
# 2871 : playertidak : playertidak
# 2872 : daerah : daerah
# 2873 : perkotaan : kota
# 2874 : okbanyak : okbanyak
# 2875 : terpencil : pencil
# 2876 : jaringanpadahal : jaringanpadahal
# 2877 : gantinya : ganti
# 2878 : sblm : sblm
# 2879 : evet : evet
# 2880 : chass : chass
# 2881 : hrga : hrga
# 2882 : kalahdan : kalahdan
# 2883 : menangsungguh : menangsungguh
# 2884 : inikita : inikita
# 2885 : bersungguhsungguh : bersungguhsungguh
# 2886 : diperbaikisemoga : diperbaikisemoga
# 2887 : mengkritik : kritik
# 2888 : keterampilan : terampil
# 2889 : ditempatkan : tempat
# 2890 : infrastruktur : infrastruktur
# 2891 : balancing : balancing
# 2892 : lakukan : laku
# 2893 : kekuatan : kuat
# 2894 : algoritma : algoritma
# 2895 : yan : yan
# 2896 : nyamanan : nyaman
# 2897 : erro : erro
# 2898 : kadng : kadng
# 2899 : grafi : graf
# 2900 : rifeshret : rifeshret
# 2901 : survivalberawalrankclasicmagic : survivalberawalrankclasicmagic
# 2902 : chesedan : chesedan
# 2903 : mausalam : mausalam
# 2904 : sbnrny : sbnrny
# 2905 : laahhhh : laahhhh
# 2906 : sesuain : sesuain
# 2907 : inovasi : inovasi
# 2908 : meminimalisir : meminimalisir
# 2909 : benarbenar : benarbenar
# 2910 : inovasinya : inovasi
# 2911 : ngurusin : ngurusin
# 2912 : mooton : mooton
# 2913 : perbaikilah : baik
# 2914 : sayaa : sayaa
# 2915 : sebagua : sebagua
# 2916 : haram : haram
# 2917 : plagiat : plagiat
# 2918 : murah : murah
# 2919 : macth : macth
# 2920 : bkan : bkan
# 2921 : newbie : newbie
# 2922 : tiernya : tiernya
# 2923 : temuka : temuka
# 2924 : terapkan : terap
# 2925 : tambahin : tambahin
# 2926 : plissssss : plissssss
# 2927 : menyepelekan : sepele
# 2928 : ketidakstabilan : ketidakstabilan
# 2929 : dialami : alami
# 2930 : ketidaknyamanan : ketidaknyamanan
# 2931 : didalamnya : dalam
# 2932 : olayer : olayer
# 2933 : setimpal : timpal
# 2934 : siatem : siatem
# 2935 : miya : miya
# 2936 : wawww : wawww
# 2937 : kerennn : kerennn
# 2938 : setting : setting
# 2939 : lagimoonton : lagimoonton
# 2940 : bermainnya : main
# 2941 : semaksimal : maksimal
# 2942 : tapu : tapu
# 2943 : sampaisampa : sampaisampa
# 2944 : harapan : harap
# 2945 : terputustapi : terputustapi
# 2946 : setiapharinya : setiapharinya
# 2947 : apdetan : apdetan
# 2948 : overdrive : overdrive
# 2949 : seosen : seosen
# 2950 : harinya : hari
# 2951 : skinherodan : skinherodan
# 2952 : colab : colab
# 2953 : narutoxmlbb : narutoxmlbb
# 2954 : tiket : tiket
# 2955 : ditukarkan : tukar
# 2956 : smpe : smpe
# 2957 : setahun : tahun
# 2958 : gada : gada
# 2959 : karyawannya : karyawannya
# 2960 : mkan : mkan
# 2961 : gaji : gaji
# 2962 : bsa : bsa
# 2963 : ksih : ksih
# 2964 : mainngetrolldark : mainngetrolldark
# 2965 : susahnya : susah
# 2966 : pagi : pagi
# 2967 : nonstop : nonstop
# 2968 : sayah : sayah
# 2969 : apdet : apdet
# 2970 : kalou : kalou
# 2971 : baonyak : baonyak
# 2972 : mengunakan : mengunakan
# 2973 : jaringganyah : jaringganyah
# 2974 : sin : sin
# 2975 : inimobile : inimobile
# 2976 : legendabang : legendabang
# 2977 : bangini : bangini
# 2978 : yatpi : yatpi
# 2979 : strees : strees
# 2980 : frustasiemosidan : frustasiemosidan
# 2981 : begituyaa : begituyaa
# 2982 : pertandingansering : pertandingansering
# 2983 : menanggimna : menanggimna
# 2984 : waktugk : waktugk
# 2985 : menaikkan : naik
# 2986 : renktidak : renktidak
# 2987 : frustasi : frustasi
# 2988 : diupdate : diupdate
# 2989 : alesan : alesan
# 2990 : disesuaikan : sesuai
# 2991 : blom : blom
# 2992 : tidur : tidur
# 2993 : naek : naek
# 2994 : pahami : paham
# 2995 : chest : chest
# 2996 : terindikasi : indikasi
# 2997 : dipertengahan : tengah
# 2998 : serunya : seru
# 2999 : dikalahkan : kalah
# 3000 : sinerginya : sinergi
# 3001 : permanen : permanen
# 3002 : imbanggiliran : imbanggiliran
# 3003 : bodohgiliran : bodohgiliran
# 3004 : rataplease : rataplease
# 3005 : drafpick : drafpick
# 3006 : rekomendasi : rekomendasi
# 3007 : pemainnya : main
# 3008 : overweak : overweak
# 3009 : menutup : tutup
# 3010 : membiarkan : biar
# 3011 : palingan : paling
# 3012 : tah : tah
# 3013 : adayg : adayg
# 3014 : malay : malay
# 3015 : indo : indo
# 3016 : stiap : stiap
# 3017 : ktemu : ktemu
# 3018 : ingetin : ingetin
# 3019 : perberat : berat
# 3020 : laporan : lapor
# 3021 : pelanggan : langgan
# 3022 : mencentang : centang
# 3023 : yatolong : yatolong
# 3024 : bgsstt : bgsstt
# 3025 : klu : klu
# 3026 : lagnyaudah : lagnyaudah
# 3027 : benerbener : benerbener
# 3028 : super : super
# 3029 : nub : nub
# 3030 : loot : loot
# 3031 : box : box
# 3032 : duit : duit
# 3033 : dapetin : dapetin
# 3034 : judi : judi
# 3035 : paytowin : paytowin
# 3036 : ngejaganya : ngejaganya
# 3037 : capekkk : capekkk
# 3038 : perjuanganya : perjuanganya
# 3039 : dapatkan : dapat
# 3040 : bar : bar
# 3041 : baiknya : baik
# 3042 : disayang : sayang
# 3043 : gemar : gemar
# 3044 : meraup : raup
# 3045 : untungan : untung
# 3046 : bermainan : main
# 3047 : hukumansama : hukumansama
# 3048 : todtotcokdekblok : todtotcokdekblok
# 3049 : falam : falam
# 3050 : makian : maki
# 3051 : tes : tes
# 3052 : fan : fan
# 3053 : lagibanyak : lagibanyak
# 3054 : desaku : desa
# 3055 : sekolahan : sekolah
# 3056 : beritahu : beritahu
# 3057 : desa : desa
# 3058 : geratis : gerat
# 3059 : dansemua : dansemua
# 3060 : donlod : donlod
# 3061 : ngapain : ngapain
# 3062 : jawabannya : jawab
# 3063 : dijamin : jamin
# 3064 : winstreakk : winstreakk
# 3065 : steress : steress
# 3066 : losetrekk : losetrekk
# 3067 : klik : klik
# 3068 : sekarangpaham : sekarangpaham
# 3069 : sukai : suka
# 3070 : banyakin : banyakin
# 3071 : mudahkan : mudah
# 3072 : lampu : lampu
# 3073 : cobalu : cobalu
# 3074 : kunyuk : kunyuk
# 3075 : malu : malu
# 3076 : temenya : temenya
# 3077 : jera : jera
# 3078 : biji : biji
# 3079 : eek : eek
# 3080 : menarikkarna : menarikkarna
# 3081 : songong : songong
# 3082 : minim : minim
# 3083 : skillapalagi : skillapalagi
# 3084 : solomatchingnya : solomatchingnya
# 3085 : bangetglory : bangetglory
# 3086 : semuadi : semuadi
# 3087 : gonor : gonor
# 3088 : mapbikin : mapbikin
# 3089 : inibikin : inibikin
# 3090 : mood : mood
# 3091 : berantakanpantesan : berantakanpantesan
# 3092 : sebelahgame : sebelahgame
# 3093 : apaapaan : apaapaan
# 3094 : ngetik : ngetik
# 3095 : butadan : butadan
# 3096 : ketikan : keti
# 3097 : kimi : kim
# 3098 : bahasa : bahasa
# 3099 : kerdit : kerdit
# 3100 : pengertian : erti
# 3101 : sangksi : sangksi
# 3102 : berjam : jam
# 3103 : diatur : atur
# 3104 : menyesal : sesal
# 3105 : bundir : bundir
# 3106 : laning : laning
# 3107 : msnext : msnext
# 3108 : besarsaya : besarsaya
# 3109 : mendownload : mendownload
# 3110 : goblog : goblog
# 3111 : gen : gen
# 3112 : jls : jls
# 3113 : makingnya : making
# 3114 : paok : paok
# 3115 : kekalahannya : kalah
# 3116 : ah : ah
# 3117 : darksistem : darksistem
# 3118 : star : star
# 3119 : biarin : biarin
# 3120 : digame : digame
# 3121 : ofking : ofking
# 3122 : donload : donload
# 3123 : reconect : reconect
# 3124 : bintangkarena : bintangkarena
# 3125 : hack : hack
# 3126 : keamanan : aman
# 3127 : sekunder : sekunder
# 3128 : tinjau : tinjau
# 3129 : upkecewa : upkecewa
# 3130 : developernya : developer
# 3131 : kamii : kami
# 3132 : lawannya : lawan
# 3133 : cuihhh : cuihhh
# 3134 : bosan : bosan
# 3135 : epiclegend : epiclegend
# 3136 : musuhlawan : musuhlawan
# 3137 : bole : bole
# 3138 : daem : daem
# 3139 : bagusi : bagus
# 3140 : sekalikadang : sekalikadang
# 3141 : disatukan : satu
# 3142 : kitaa : kitaa
# 3143 : nickname : nickname
# 3144 : menangani : tangan
# 3145 : follow : follow
# 3146 : karen : karen
# 3147 : a : a
# 3148 : terhambat : hambat
# 3149 : info : info
# 3150 : persaingan : saing
# 3151 : arcade : arcade
# 3152 : setuju : tuju
# 3153 : teken : teken
# 3154 : kenak : nak
# 3155 : legg : legg
# 3156 : nyatapi : nyatapi
# 3157 : perbarui : baru
# 3158 : karuan : karuan
# 3159 : jelaskasih : jelaskasih
# 3160 : terhormatgame : terhormatgame
# 3161 : losetrak : losetrak
# 3162 : hyper : hyper
# 3163 : menyandingkan : sanding
# 3164 : timjika : timjika
# 3165 : umumkan : umum
# 3166 : install : install
# 3167 : dahmakin : dahmakin
# 3168 : menyentuh : sentuh
# 3169 : tanggapi : tanggap
# 3170 : paketan : paket
# 3171 : dibes : dibes
# 3172 : babi : babi
# 3173 : menjadikan : jadi
# 3174 : tempur : tempur
# 3175 : updet : updet
# 3176 : ktika : ktika
# 3177 : dibantu : bantu
# 3178 : sahari : sahari
# 3179 : semalem : semalem
# 3180 : mulumonton : mulumonton
# 3181 : bintngnya : bintngnya
# 3182 : drack : drack
# 3183 : sunggu : sunggu
# 3184 : ngeri : ngeri
# 3185 : tahunn : tahunn
# 3186 : biasakalu : biasakalu
# 3187 : lasung : lasung
# 3188 : ngelackkalu : ngelackkalu
# 3189 : sistemkalu : sistemkalu
# 3190 : baguslevel : baguslevel
# 3191 : nalarteruskan : nalarteruskan
# 3192 : kejelekannmu : kejelekannmu
# 3193 : pinter : pinter
# 3194 : rotasi : rotasi
# 3195 : matifeed : matifeed
# 3196 : gitulah : gitulah
# 3197 : siang : siang
# 3198 : jump : jump
# 3199 : jelekkkk : jelekkkk
# 3200 : ajg : ajg
# 3201 : seharian : hari
# 3202 : trolpenghuni : trolpenghuni
# 3203 : matian : mati
# 3204 : ush : ush
# 3205 : dipencet : pencet
# 3206 : fakta : fakta
# 3207 : gloryimmortal : gloryimmortal
# 3208 : babiq : babiq
# 3209 : ketagihan : tagih
# 3210 : tersenyum : senyum
# 3211 : beruntung : untung
# 3212 : memotivasi : motivasi
# 3213 : berasabar : berasabar
# 3214 : sifat : sifat
# 3215 : bebaltidak : bebaltidak
# 3216 : mengikuti : ikut
# 3217 : ajakan : aja
# 3218 : teambuta : teambuta
# 3219 : mapdan : mapdan
# 3220 : rotasidan : rotasidan
# 3221 : yaasekian : yaasekian
# 3222 : bebenah : bebenah
# 3223 : sepi : sepi
# 3224 : lma : lma
# 3225 : campur : campur
# 3226 : kesmua : kesmua
# 3227 : seminggu : minggu
# 3228 : kapok : kapok
# 3229 : gra : gra
# 3230 : why : why
# 3231 : moontonwhy : moontonwhy
# 3232 : ranknha : ranknha
# 3233 : padahl : padahl
# 3234 : glorydan : glorydan
# 3235 : diperbaikidan : diperbaikidan
# 3236 : ramah : ramah
# 3237 : lapor : lapor
# 3238 : mlnya : mlnya
# 3239 : bugbanyak : bugbanyak
# 3240 : seimbangmana : seimbangmana
# 3241 : terberatsignal : terberatsignal
# 3242 : merahadmint : merahadmint
# 3243 : berperan : peran
# 3244 : dinaik : naik
# 3245 : kangame : kangame
# 3246 : khusus : khusus
# 3247 : skinsori : skinsori
# 3248 : dideteksi : deteksi
# 3249 : penyebab : sebab
# 3250 : moontonsekian : moontonsekian
# 3251 : stabiltim : stabiltim
# 3252 : imbangga : imbangga
# 3253 : mentang : mentang
# 3254 : divisi : divisi
# 3255 : buattin : buattin
# 3256 : recal : recal
# 3257 : bjir : bjir
# 3258 : postin : postin
# 3259 : rateting : rateting
# 3260 : personal : personal
# 3261 : jelasmasa : jelasmasa
# 3262 : legendnya : legendnya
# 3263 : betulin : betulin
# 3264 : tutup : tutup
# 3265 : turuninscor : turuninscor
# 3266 : bintangcaranyagamers : bintangcaranyagamers
# 3267 : sejatipunya : sejatipunya
# 3268 : nyawajumpa : nyawajumpa
# 3269 : begomaju : begomaju
# 3270 : selangkah : selang
# 3271 : mundurnya : mundur
# 3272 : langkah : langkah
# 3273 : gamerspro : gamerspro
# 3274 : pepatah : pepatah
# 3275 : mngatakan : mngatakan
# 3276 : jatuh : jatuh
# 3277 : ditimpa : timpa
# 3278 : tanggaketimpa : tanggaketimpa
# 3279 : telor : telor
# 3280 : baiktutupakun : baiktutupakun
# 3281 : inijd : inijd
# 3282 : dongcontohnya : dongcontohnya
# 3283 : tdi : tdi
# 3284 : sperti : sperti
# 3285 : gamersseruuuuuuuu : gamersseruuuuuuuu
# 3286 : apdate : apdate
# 3287 : lucas : lucas
# 3288 : lees : lees
# 3289 : jad : jad
# 3290 : pingnya : pingnya
# 3291 : makiin : makiin
# 3292 : coo : coo
# 3293 : wifikuota : wifikuota
# 3294 : fans : fans
# 3295 : andalin : andalin
# 3296 : bt : bt
# 3297 : brp : brp
# 3298 : ngitung : ngitung
# 3299 : kebanyakannya : banyak
# 3300 : mastiin : mastiin
# 3301 : ngebuff : ngebuff
# 3302 : jung : jung
# 3303 : sekarat : sekarat
# 3304 : nyawanya : nyawa
# 3305 : cirinya : ciri
# 3306 : dehhhhhhhhh : dehhhhhhhhh
# 3307 : kerjaannya : kerja
# 3308 : saranku : saran
# 3309 : musuhtim : musuhtim
# 3310 : taiii : taiii
# 3311 : kucing : kucing
# 3312 : ternyta : ternyta
# 3313 : seasosn : seasosn
# 3314 : sampahh : sampahh
# 3315 : katemu : kate
# 3316 : judol : judol
# 3317 : ditinggalkan : tinggal
# 3318 : ge : ge
# 3319 : ng : ng
# 3320 : oah : oah
# 3321 : ujungujung : ujungujung
# 3322 : tpitolong : tpitolong
# 3323 : solobuat : solobuat
# 3324 : kompakbahkan : kompakbahkan
# 3325 : partiansedang : partiansedang
# 3326 : devploper : devploper
# 3327 : melaporkan : lapor
# 3328 : kesenangan : senang
# 3329 : oprator : oprator
# 3330 : menyenangakan : menyenangakan
# 3331 : setela : setela
# 3332 : iseng : iseng
# 3333 : eehhh : eehhh
# 3334 : robot : robot
# 3335 : bagusan : bagus
# 3336 : ai : ai
# 3337 : auto : auto
# 3338 : dehhhh : dehhhh
# 3339 : esssmosi : esssmosi
# 3340 : wariior : wariior
# 3341 : mayyytikmana : mayyytikmana
# 3342 : partisipasi : partisipasi
# 3343 : ngancurin : ngancurin
# 3344 : berkontribusi : kontribusi
# 3345 : setidak : tidak
# 3346 : lahjangan : lahjangan
# 3347 : kitamasa : kitamasa
# 3348 : lejen : lejen
# 3349 : machking : machking
# 3350 : cece : cece
# 3351 : jarian : jari
# 3352 : pencet : pencet
# 3353 : basic : basic
# 3354 : atack : atack
# 3355 : gatsu : gatsu
# 3356 : survival : survival
# 3357 : kembaliin : kembaliin
# 3358 : tiketnya : tiket
# 3359 : masaniya : masaniya
# 3360 : dm : dm
# 3361 : kirakira : kirakira
# 3362 : memo : memo
# 3363 : ful : ful
# 3364 : sudut : sudut
# 3365 : tapiiiiiiiiiiiiiiii : tapiiiiiiiiiiiiiiii
# 3366 : palayer : palayer
# 3367 : berprilaku : berprilaku
# 3368 : angtain : angtain
# 3369 : kenal : kenal
# 3370 : mem : mem
# 3371 : bintanga : bintanga
# 3372 : saking : saking
# 3373 : bersikap : sikap
# 3374 : jugaku : juga
# 3375 : gaen : gaen
# 3376 : karan : karan
# 3377 : afkngetrol : afkngetrol
# 3378 : situlah : situ
# 3379 : menam : tam
# 3380 : bah : bah
# 3381 : portiksion : portiksion
# 3382 : kompen : kompen
# 3383 : sasi : sasi
# 3384 : bintan : bintan
# 3385 : filter : filter
# 3386 : jdinya : jdinya
# 3387 : cheese : cheese
# 3388 : spesifik : spesifik
# 3389 : command : command
# 3390 : persentase : persentase
# 3391 : nyarinya : nyarinya
# 3392 : usahain : usahain
# 3393 : gedek : gedek
# 3394 : sreak : sreak
# 3395 : ekosistem : ekosistem
# 3396 : kombo : kombo
# 3397 : sinergi : sinergi
# 3398 : commander : commander
# 3399 : dinerf : dinerf
# 3400 : buss : buss
# 3401 : tharz : tharz
# 3402 : vale : vale
# 3403 : early : early
# 3404 : dibukaupdate : dibukaupdate
# 3405 : tambak : tambak
# 3406 : masalahudah : masalahudah
# 3407 : bisaudah : bisaudah
# 3408 : ristar : ristar
# 3409 : bisatolong : bisatolong
# 3410 : draftnya : draftnya
# 3411 : acakan : acak
# 3412 : imortal : imortal
# 3413 : bersahabat : sahabat
# 3414 : hook : hook
# 3415 : jelasmakin : jelasmakin
# 3416 : munculmakin : munculmakin
# 3417 : meresahkan : resah
# 3418 : sampek : sampek
# 3419 : berhari : hari
# 3420 : hariwajib : hariwajib
# 3421 : sinya : sinya
# 3422 : hilanglag : hilanglag
# 3423 : jelasni : jelasni
# 3424 : lagitolong : lagitolong
# 3425 : carikan : cari
# 3426 : seimbanggmain : seimbanggmain
# 3427 : elit : elit
# 3428 : aspek : aspek
# 3429 : komunitas : komunitas
# 3430 : pribadi : pribadi
# 3431 : feedingskill : feedingskill
# 3432 : cenderung : cenderung
# 3433 : begroun : begroun
# 3434 : berserta : serta
# 3435 : musiknya : musik
# 3436 : ilangkaya : ilangkaya
# 3437 : jauhin : jauhin
# 3438 : jauhkan : jauh
# 3439 : memperjelek : jelek
# 3440 : losstreak : losstreak
# 3441 : presentasi : presentasi
# 3442 : dilepas : lepas
# 3443 : moonhon : moonhon
# 3444 : terisi : isi
# 3445 : kdng : kdng
# 3446 : rolenya : rolenya
# 3447 : ngambek : ngambek
# 3448 : bisabisanya : bisabisanya
# 3449 : berturutturut : berturutturut
# 3450 : padalan : padalan
# 3451 : ahhsudahlah : ahhsudahlah
# 3452 : recall : recall
# 3453 : emotnya : emotnya
# 3454 : ucapkan : ucap
# 3455 : asyik : asyik
# 3456 : skrang : skrang
# 3457 : machmaking : machmaking
# 3458 : erorin : erorin
# 3459 : lambatin : lambatin
# 3460 : klihatan : klihatan
# 3461 : devet : devet
# 3462 : fnmskn : fnmskn
# 3463 : kekecewaan : kecewa
# 3464 : mengutuk : kutuk
# 3465 : sedalam : dalam
# 3466 : ancurr : ancurr
# 3467 : sehancur : hancur
# 3468 : mengalaminya : alam
# 3469 : segan : segan
# 3470 : mengajak : ajak
# 3471 : aplokasi : aplokasi
# 3472 : mpv : mpv
# 3473 : km : km
# 3474 : coment : coment
# 3475 : negatif : negatif
# 3476 : ujungnyaheromu : ujungnyaheromu
# 3477 : menyesuaikan : sesuai
# 3478 : lawandan : lawandan
# 3479 : lawansaya : lawansaya
# 3480 : rankdan : rankdan
# 3481 : ara : ara
# 3482 : nyaagar : nyaagar
# 3483 : sepenuhnya : sepenuh
# 3484 : undang : undang
# 3485 : samasama : samasama
# 3486 : rilog : rilog
# 3487 : comender : comender
# 3488 : thars : thars
# 3489 : seakan : akan
# 3490 : sinergj : sinergj
# 3491 : bangun : bangun
# 3492 : melawan : lawan
# 3493 : tertingginya : tinggi
# 3494 : permasalahan : masalah
# 3495 : meredakan : reda
# 3496 : kerjaan : kerja
# 3497 : sdah : sdah
# 3498 : betrik : betrik
# 3499 : msalah : msalah
# 3500 : dmage : dmage
# 3501 : tdak : tdak
# 3502 : mrasman : mrasman
# 3503 : pling : pling
# 3504 : mnurut : mnurut
# 3505 : slam : slam
# 3506 : liht : liht
# 3507 : kurng : kurng
# 3508 : slama : slama
# 3509 : dkit : dkit
# 3510 : imbangi : imbang
# 3511 : perbaik : baik
# 3512 : wkwk : wkwk
# 3513 : analog : analog
# 3514 : lepas : lepas
# 3515 : terusudah : terusudah
# 3516 : sia : sia
# 3517 : nasib : nasib
# 3518 : ahh : ahh
# 3519 : diblacklist : diblacklist
# 3520 : berkomunikasi : komunikasi
# 3521 : tambahkan : tambah
# 3522 : kapasitas : kapasitas
# 3523 : verbal : verbal
# 3524 : abuse : abuse
# 3525 : mengetik : etik
# 3526 : pendek : pendek
# 3527 : lance : lance
# 3528 : direspon : direspon
# 3529 : leq : leq
# 3530 : it : it
# 3531 : mumuaskan : mumuaskan
# 3532 : amin : amin
# 3533 : penjelasannya : jelas
# 3534 : wasuuu : wasuuu
# 3535 : amit : amit
# 3536 : ajah : ajah
# 3537 : seringin : ringin
# 3538 : dikitmatchmaching : dikitmatchmaching
# 3539 : gwmohon : gwmohon
# 3540 : drapick : drapick
# 3541 : rolle : rolle
# 3542 : plyar : plyar
# 3543 : drapicknya : drapicknya
# 3544 : lawanya : lawa
# 3545 : ngefreez : ngefreez
# 3546 : credits : credits
# 3547 : da : da
# 3548 : opratornya : opratornya
# 3549 : akunya : aku
# 3550 : baperan : baperan
# 3551 : diban : ban
# 3552 : terbukti : bukti
# 3553 : diperjelas : jelas
# 3554 : k : k
# 3555 : blakangan : blakangan
# 3556 : stabilitas : stabilitas
# 3557 : potensi : potensi
# 3558 : mencakup : cakup
# 3559 : konstan : konstan
# 3560 : pemutusan : putus
# 3561 : konektivitas : konektivitas
# 3562 : realtime : realtime
# 3563 : multiplayer : multiplayer
# 3564 : playerkarena : playerkarena
# 3565 : dropdan : dropdan
# 3566 : lagimasalah : lagimasalah
# 3567 : nglaqdlm : nglaqdlm
# 3568 : bagusbenahin : bagusbenahin
# 3569 : klaim : klaim
# 3570 : reflek : reflek
# 3571 : berbakat : bakat
# 3572 : berakal : akal
# 3573 : yamg : yamg
# 3574 : meneganggakan : meneganggakan
# 3575 : intuisi : intuisi
# 3576 : kefokusan : fokus
# 3577 : meningkat : tingkat
# 3578 : berfikir : berfikir
# 3579 : berfokus : fokus
# 3580 : tolenrasi : tolenrasi
# 3581 : chipset : chipset
# 3582 : helio : hio
# 3583 : drpd : drpd
# 3584 : diperbaikidiminimalisir : diperbaikidiminimalisir
# 3585 : pasahal : pasahal
# 3586 : poco : poco
# 3587 : ketik : ketik
# 3588 : adik : adik
# 3589 : kreditscore : kreditscore
# 3590 : upgreat : upgreat
# 3591 : mundurin : mundurin
# 3592 : video : video
# 3593 : mesti : mesti
# 3594 : menerima : terima
# 3595 : kehilangan : hilang
# 3596 : hargai : harga
# 3597 : ngedratf : ngedratf
# 3598 : surender : surender
# 3599 : disaat : saat
# 3600 : high : high
# 3601 : domino : domino
# 3602 : mengakui : aku
# 3603 : imbangkan : imbang
# 3604 : ituitu : ituitu
# 3605 : wrwb : wrwb
# 3606 : reconnect : reconnect
# 3607 : belabelain : belabelain
# 3608 : kalahmenang : kalahmenang
# 3609 : butaa : butaa
# 3610 : kejadian : jadi
# 3611 : sayasaya : sayasaya
# 3612 : freezedari : freezedari
# 3613 : beginisaat : beginisaat
# 3614 : voucher : voucher
# 3615 : jugalah : juga
# 3616 : dayanya : daya
# 3617 : diseimbangkan : imbang
# 3618 : machmakingnya : machmakingnya
# 3619 : bisaa : bisaa
# 3620 : gaaa : gaaa
# 3621 : rusakkkkkkk : rusakkkkkkk
# 3622 : sendirikeluh : sendirikeluh
# 3623 : atasi : atas
# 3624 : gratiss : gratiss
# 3625 : signifikan : signifikan
# 3626 : apalgi : apalgi
# 3627 : sekrang : sekrang
# 3628 : temu : temu
# 3629 : buruan : buru
# 3630 : delete : delete
# 3631 : bunuh : bunuh
# 3632 : jirrr : jirrr
# 3633 : ngide : ngide
# 3634 : dibuka : buka
# 3635 : serching : serching
# 3636 : kebuka : buka
# 3637 : bangbang : bangbang
# 3638 : keulang : ulang
# 3639 : bolak : bolak
# 3640 : ngetroldrak : ngetroldrak
# 3641 : klok : klok
# 3642 : laporkan : lapor
# 3643 : kasik : kasik
# 3644 : mainnyagua : mainnyagua
# 3645 : userdrak : userdrak
# 3646 : dikabulkan : kabul
# 3647 : canggih : canggih
# 3648 : besarbesaran : besarbesaran
# 3649 : legenda : legenda
# 3650 : pengembangnya : kembang
# 3651 : set : set
# 3652 : develover : develover
# 3653 : dibedakan : beda
# 3654 : digabung : gabung
# 3655 : pembaruan : baru
# 3656 : lawas : lawas
# 3657 : losestreakmvp : losestreakmvp
# 3658 : ngelglike : ngelglike
# 3659 : nyalakan : nyala
# 3660 : speed : speed
# 3661 : lwnnya : lwnnya
# 3662 : mengtik : mengtik
# 3663 : sensor : sensor
# 3664 : ketat : ketat
# 3665 : anehsistem : anehsistem
# 3666 : logisdapet : logisdapet
# 3667 : invalidgiliran : invalidgiliran
# 3668 : roll : roll
# 3669 : semuatrus : semuatrus
# 3670 : semuaalhasil : semuaalhasil
# 3671 : xpgoldmidcoba : xpgoldmidcoba
# 3672 : bsukk : bsukk
# 3673 : tersedia : sedia
# 3674 : math : math
# 3675 : flash : flash
# 3676 : wa : wa
# 3677 : mlugame : mlugame
# 3678 : syg : syg
# 3679 : kerentapi : rentap
# 3680 : masalahnyaharusnya : masalahnyaharusnya
# 3681 : pintarjadi : pintarjadi
# 3682 : mempertimbangkan : timbang
# 3683 : gj : gj
# 3684 : sisanya : sisa
# 3685 : brengsek : brengsek
# 3686 : kayaknya : kayak
# 3687 : ntar : ntar
# 3688 : penipu : tipu
# 3689 : ranking : ranking
# 3690 : matilah : mati
# 3691 : playerdisetting : playerdisetting
# 3692 : playerotak : playerotak
# 3693 : matchmakingjaringan : matchmakingjaringan
# 3694 : nyiptain : nyiptain
# 3695 : nyepin : nyepin
# 3696 : dulusoalnya : dulusoalnya
# 3697 : halo : halo
# 3698 : pingsetiap : pingsetiap
# 3699 : treakdari : treakdari
# 3700 : gerakan : gera
# 3701 : mumpung : mumpung
# 3702 : papi : papi
# 3703 : streek : streek
# 3704 : dart : dart
# 3705 : peka : peka
# 3706 : dihiraukan : hirau
# 3707 : dipertimbangkan : timbang
# 3708 : diatasin : diatasin
# 3709 : bicara : bicara
# 3710 : membeli : beli
# 3711 : epiclegends : epiclegends
# 3712 : wkwkwwkekwel : wkwkwwkekwel
# 3713 : perbaikisaat : perbaikisaat
# 3714 : truss : truss
# 3715 : jaringannyakenapa : jaringannyakenapa
# 3716 : mainjadi : mainjadi
# 3717 : patahpatah : patahpatah
# 3718 : ringankanlah : ringan
# 3719 : eventeventnya : eventeventnya
# 3720 : dipermurah : murah
# 3721 : dioptimalkan : optimal
# 3722 : disensor : sensor
# 3723 : bersilaturahmi : silaturahmi
# 3724 : suasana : suasana
# 3725 : mengasikan : asi
# 3726 : terbitlah : terbit
# 3727 : bersenang : senang
# 3728 : anjurkan : anjur
# 3729 : pemarah : marah
# 3730 : trolya : trolya
# 3731 : botdongo : botdongo
# 3732 : lagngeframe : lagngeframe
# 3733 : gd : gd
# 3734 : stabilbagus : stabilbagus
# 3735 : puasa : puasa
# 3736 : kl : kl
# 3737 : apasi : apas
# 3738 : cukupkarna : cukupkarna
# 3739 : jelasapalagi : jelasapalagi
# 3740 : iniseason : iniseason
# 3741 : jelasudah : jelasudah
# 3742 : selesaitiba : selesaitiba
# 3743 : lobbyga : lobbyga
# 3744 : menangmudah : menangmudah
# 3745 : tmenya : tmenya
# 3746 : smuaprcuma : smuaprcuma
# 3747 : atteknya : atteknya
# 3748 : nanggung : nanggung
# 3749 : pecinta : cinta
# 3750 : cranyatrimakasih : cranyatrimakasih
# 3751 : perporma : perporma
# 3752 : chet : chet
# 3753 : pening : pening
# 3754 : seber : seber
# 3755 : ajha : ajha
# 3756 : macetlag : macetlag
# 3757 : lagmacet : lagmacet
# 3758 : midle : midle
# 3759 : gangguin : gangguin
# 3760 : bagusnya : bagus
# 3761 : ton : ton
# 3762 : lumayantapi : lumayantapi
# 3763 : nyebelin : nyebelin
# 3764 : ngatasin : ngatasin
# 3765 : land : land
# 3766 : diloby : diloby
# 3767 : kocaknya : kocak
# 3768 : gituhal : gituhal
# 3769 : ganggu : ganggu
# 3770 : akuu : akuu
# 3771 : cinta : cinta
# 3772 : gamee : gamee
# 3773 : seruu : seruu
# 3774 : dann : dann
# 3775 : membuatt : membuatt
# 3776 : lega : lega
# 3777 : santun : santun
# 3778 : mengisi : isi
# 3779 : luang : luang
# 3780 : bola : bola
# 3781 : bale : bale
# 3782 : masah : masah
# 3783 : cemn : cemn
# 3784 : mwu : mwu
# 3785 : penggemar : gemar
# 3786 : banya : banya
# 3787 : menyala : nyala
# 3788 : spaya : spaya
# 3789 : pke : pke
# 3790 : ajh : ajh
# 3791 : legh : legh
# 3792 : s : s
# 3793 : selaras : selaras
# 3794 : derita : derita
# 3795 : krn : krn
# 3796 : tautau : tautau
# 3797 : bbn : bbn
# 3798 : keorang : orang
# 3799 : upgrade : upgrade
# 3800 : pentingkan : penting
# 3801 : sky : sky
# 3802 : piecer : piecer
# 3803 : dps : dps
# 3804 : change : change
# 3805 : attack : attack
# 3806 : fighter : fighter
# 3807 : keluarkan : keluar
# 3808 : dulunya : dulunya
# 3809 : pasaran : pasar
# 3810 : fragmentbattlepoint : fragmentbattlepoint
# 3811 : dihadiahkandiberikan : dihadiahkandiberikan
# 3812 : konversi : konversi
# 3813 : paspas : paspas
# 3814 : berterimakasih : berterimakasih
# 3815 : menggabungkan : gabung
# 3816 : pemakaian : pakai
# 3817 : menyigung : sigung
# 3818 : mengusahakan : usaha
# 3819 : mendunia : dunia
# 3820 : kumainkan : main
# 3821 : wooy : wooy
# 3822 : anjiing : anjiing
# 3823 : laag : laag
# 3824 : pelayanan : layan
# 3825 : roleplay : roleplay
# 3826 : menyusahkan : susah
# 3827 : memperhatikan : perhati
# 3828 : dilock : dilock
# 3829 : berbelit : belit
# 3830 : belit : belit
# 3831 : perarturannya : perarturannya
# 3832 : komendasikan : komendasikan
# 3833 : fasilitas : fasilitas
# 3834 : tampilannya : tampil
# 3835 : dikitkarena : dikitkarena
# 3836 : tibalah : tiba
# 3837 : sngat : sngat
# 3838 : merasakannya : rasa
# 3839 : rindu : rindu
# 3840 : tanggapan : tanggap
# 3841 : playaer : playaer
# 3842 : slamat : slamat
# 3843 : bnar : bnar
# 3844 : draksistem : draksistem
# 3845 : tabrak : tabrak
# 3846 : baf : baf
# 3847 : berulah : ulah
# 3848 : gituudh : gituudh
# 3849 : melekat : lekat
# 3850 : obatin : obatin
# 3851 : katain : katain
# 3852 : parahnya : parah
# 3853 : advance : advance
# 3854 : vanguard : vanguard
# 3855 : suply : suply
# 3856 : diakses : akses
# 3857 : brawel : brawel
# 3858 : diturunin : diturunin
# 3859 : ekspektasi : ekspektasi
# 3860 : bkn : bkn
# 3861 : tank : tank
# 3862 : sukses : sukses
# 3863 : penjoki : joki
# 3864 : montonn : montonn
# 3865 : ancurrt : ancurrt
# 3866 : suu : suu
# 3867 : setelag : setelag
# 3868 : assalamualaikum : assalamualaikum
# 3869 : mlh : mlh
# 3870 : memperparah : parah
# 3871 : terkesan : kes
# 3872 : maki : maki
# 3873 : wife : wife
# 3874 : muluudah : muluudah
# 3875 : ggnya : ggnya
# 3876 : iven : iven
# 3877 : trimaksih : trimaksih
# 3878 : blum : blum
# 3879 : ply : ply
# 3880 : seimbangtim : seimbangtim
# 3881 : mainnyakalo : mainnyakalo
# 3882 : mlgeme : mlgeme
# 3883 : sepertiku : seperti
# 3884 : sudahh : sudahh
# 3885 : vidio : vidio
# 3886 : munduragar : munduragar
# 3887 : mempermudah : mudah
# 3888 : mengedit : edit
# 3889 : merekabanyak : merekabanyak
# 3890 : trimakasih : trimakasih
# 3891 : brapa : brapa
# 3892 : majapahittidak : majapahittidak
# 3893 : seharus : harus
# 3894 : pelindung : lindung
# 3895 : terhibur : hibur
# 3896 : depeloper : depeloper
# 3897 : jamin : jamin
# 3898 : apes : apes
# 3899 : teamfight : teamfight
# 3900 : dipatch : dipatch
# 3901 : kerjanya : kerja
# 3902 : etika : etika
# 3903 : kelancaran : lancar
# 3904 : updatetan : updatetan
# 3905 : semuanyaaa : semuanyaaa
# 3906 : ajakin : ajakin
# 3907 : by : by
# 3908 : one : one
# 3909 : custom : custom
# 3910 : niiih : niiih
# 3911 : ngjakin : ngjakin
# 3912 : paus : paus
# 3913 : komputrnya : komputrnya
# 3914 : tk : tk
# 3915 : ot : ot
# 3916 : ninym : ninym
# 3917 : ralei : ralei
# 3918 : ninymralei : ninymralei
# 3919 : janji : janji
# 3920 : waktumainnya : waktumainnya
# 3921 : maennya : maennya
# 3922 : botnya : bot
# 3923 : pendapat : dapat
# 3924 : neko : neko
# 3925 : kga : kga
# 3926 : imo : imo
# 3927 : jadiin : jadiin
# 3928 : partian : partian
# 3929 : sorry : sorry
# 3930 : komplain : komplain
# 3931 : angst : angst
# 3932 : sekalimenuru : sekalimenuru
# 3933 : nyamatch : nyamatch
# 3934 : lainpercuma : lainpercuma
# 3935 : kolektor : kolektor
# 3936 : lagtolong : lagtolong
# 3937 : sayakalian : sayakalian
# 3938 : arti : arti
# 3939 : kekompakan : kompak
# 3940 : kesabaran : sabar
# 3941 : bacotin : bacotin
# 3942 : banyakdan : banyakdan
# 3943 : dimengerti : erti
# 3944 : goodluck : goodluck
# 3945 : taiiiiiii : taiiiiiii
# 3946 : ter : ter
# 3947 : taiiii : taiiii
# 3948 : sejarah : sejarah
# 3949 : karakter : karakter
# 3950 : enaken : enaken
# 3951 : balmon : balmon
# 3952 : matidan : matidan
# 3953 : air : air
# 3954 : api : api
# 3955 : sembunyi : sembunyi
# 3956 : rahasia : rahasia
# 3957 : tahannafasdibawahadadm : tahannafasdibawahadadm
# 3958 : situasi : situasi
# 3959 : dibanding : banding
# 3960 : dahgua : dahgua
# 3961 : legendni : legendni
# 3962 : adilcoba : adilcoba
# 3963 : botmending : botmending
# 3964 : mainapa : mainapa
# 3965 : moontongua : moontongua
# 3966 : epiktolong : epiktolong
# 3967 : akalitu : akalitu
# 3968 : yangg : yangg
# 3969 : terdektesi : terdektesi
# 3970 : kesalah : salah
# 3971 : becanda : becanda
# 3972 : digunain : digunain
# 3973 : tmm : tmm
# 3974 : pus : pus
# 3975 : hehehe : hehehe
# 3976 : buatin : buatin
# 3977 : kelas : kelas
# 3978 : smp : smp
# 3979 : epep : epep
# 3980 : kuata : kuata
# 3981 : boros : boros
# 3982 : hemat : hemat
# 3983 : bangbangpercuma : bangbangpercuma
# 3984 : colector : colector
# 3985 : menghendel : hendel
# 3986 : indosaya : indosaya
# 3987 : pingjaringan : pingjaringan
# 3988 : memperbaikin : memperbaikin
# 3989 : hukumn : hukumn
# 3990 : singkat : singkat
# 3991 : mengesalkan : kesal
# 3992 : kedalam : dalam
# 3993 : dikalah : kalah
# 3994 : grade : grade
# 3995 : hulangan : hulangan
# 3996 : buruh : buruh
# 3997 : bagusgrafiknya : bagusgrafiknya
# 3998 : oketapi : oketapi
# 3999 : bugcontoh : bugcontoh
# 4000 : lagsemoga : lagsemoga
# 4001 : bodo : bodo
# 4002 : teroos : teroos
# 4003 : well : well
# 4004 : bdo : bdo
# 4005 : trun : trun
# 4006 : maksud : maksud
# 4007 : menjatuh : jatuh
# 4008 : sekejap : kejap
# 4009 : berkedipkedip : berkedipkedip
# 4010 : menggangudan : menggangudan
# 4011 : spawn : spawn
# 4012 : dab : dab
# 4013 : sapa : sapa
# 4014 : unuk : unuk
# 4015 : menghidari : menghidari
# 4016 : sereng : sereng
# 4017 : muter : muter
# 4018 : miytik : miytik
# 4019 : easy : easy
# 4020 : hardcore : hardcore
# 4021 : bakat : bakat
# 4022 : terpendam : pendam
# 4023 : bangkit : bangkit
# 4024 : yasaya : yasaya
# 4025 : sistemketika : sistemketika
# 4026 : nyawa : nyawa
# 4027 : sekaratmengapa : sekaratmengapa
# 4028 : kesusahan : susah
# 4029 : oi : oi
# 4030 : bocil : bocil
# 4031 : jgan : jgan
# 4032 : naikan : naik
# 4033 : benaran : benar
# 4034 : counter : counter
# 4035 : ngegame : ngegame
# 4036 : pt : pt
# 4037 : parahhh : parahhh
# 4038 : engkau : engkau
# 4039 : kedepenya : kedepenya
# 4040 : berbaik : baik
# 4041 : sm : sm
# 4042 : steres : steres
# 4043 : sni : sni
# 4044 : lagnya : lagnya
# 4045 : gerakjaringan : gerakjaringan
# 4046 : streaks : streaks
# 4047 : pegel : gel
# 4048 : punggung : punggung
# 4049 : montod : montod
# 4050 : imbas : imbas
# 4051 : stabilkan : stabil
# 4052 : moontoddd : moontoddd
# 4053 : desain : desain
# 4054 : elite : elite
# 4055 : grafikevent : grafikevent
# 4056 : disandingkan : sanding
# 4057 : solojadi : solojadi
# 4058 : solosaran : solosaran
# 4059 : tlool : tlool
# 4060 : sebentar : sebentar
# 4061 : mactmaking : mactmaking
# 4062 : anime : anime
# 4063 : tingkatin : tingkatin
# 4064 : kastanya : kasta
# ...
# 6923 : dahdari : dahdari
# 6924 : my : my
# 6925 : tipis : tipis
# 6926 : dijalankan : jalan
# 6927 : terhapus : hapus
# 6928 : saatapalagi : saatapalagi
# 6929 : parming : parming
# 6930 : badut : badut
# 6931 : ginigua : ginigua
# 6932 : skinntim : skinntim
# 6933 : mulugak : mulugak
# 6934 : musuhcoba : musuhcoba
# 6935 : logis : logis
# 6936 : logikangasih : logikangasih
# 6937 : ngelawak : ngelawak
# 6938 : downloadnanti : downloadnanti
# 6939 : hy : hy
# 6940 : deploper : deploper
# 6941 : sayadisini : sayadisini
# 6942 : lebihnya : lebih
# 6943 : penyimpan : simpan
# 6944 : urusin : urusin
# 6945 : sebelahga : sebelahga
# 6946 : muluk : muluk
# 6947 : graphic : graphic
# 6948 : mengutamakan : utama
# 6949 : segini : gin
# 6950 : kece : kece
# 6951 : anjirrr : anjirrr
# 6952 : trjadi : trjadi
# 6953 : kesan : kesan
# 6954 : tentuin : tentuin
# 6955 : njirrr : njirrr
# 6956 : pdaha : pdaha
# 6957 : sampk : sampk
# 6958 : buruksetelah : buruksetelah
# 6959 : yapadahal : yapadahal
# 6960 : sendiriuntuk : sendiriuntuk
# 6961 : pik : pik
# 6962 : barumasuk : barumasuk
# 6963 : tpmbol : tpmbol
# 6964 : attak : attak
# 6965 : ladang : ladang
# 6966 : nexs : nexs
# 6967 : vyang : vyang
# 6968 : diadain : diadain
# 6969 : duh : duh
# 6970 : reno : reno
# 6971 : f : f
# 6972 : devicenya : devicenya
# 6973 : sesegerah : gerah
# 6974 : oyy : oyy
# 6975 : keriset : riset
# 6976 : rw : rw
# 6977 : bebaskan : bebas
# 6978 : alasanyaitu : alasanyaitu
# 6979 : bgo : bgo
# 6980 : lanjutkantapi : lanjutkantapi
# 6981 : misalny : misalny
# 6982 : jaringanny : jaringanny
# 6983 : sngt : sngt
# 6984 : lainmohon : lainmohon
# 6985 : menyebarkan : sebar
# 6986 : komputerdark : komputerdark
# 6987 : mbat : mbat
# 6988 : abisan : abis
# 6989 : pengaduan : adu
# 6990 : menghukum : hukum
# 6991 : hemmmm : hemmmm
# 6992 : ultimatenya : ultimatenya
# 6993 : improve : improve
# 6994 : asuuuuuu : asuuuuuu
# 6995 : jingan : jingan
# 6996 : akhlaq : akhlaq
# 6997 : menderita : derita
# 6998 : lostrekditambah : lostrekditambah
# 6999 : kanbelum : kanbelum
# 7000 : ajaterlebih : ajaterlebih
# 7001 : winapaan : winapaan
# 7002 : sampei : sampei
# 7003 : luarbiasa : luarbiasa
# 7004 : grafikdan : grafikdan
# 7005 : kualitasnya : kualitas
# 7006 : garing : garing
# 7007 : harganya : harga
# 7008 : premium : premium
# 7009 : abiss : abiss
# 7010 : ranting : ranting
# 7011 : berbicara : bicara
# 7012 : manis : manis
# 7013 : memancing : pancing
# 7014 : pkok : pkok
# 7015 : bas : bas
# 7016 : matcmacing : matcmacing
# 7017 : pebaiki : baik
# 7018 : dmn : dmn
# 7019 : lwan : lwan
# 7020 : melengkapi : lengkap
# 7021 : sasaran : sasar
# 7022 : keode : ode
# 7023 : seolaholah : seolaholah
# 7024 : chese : chese
# 7025 : ajasetiap : ajasetiap
# 7026 : menangpas : menangpas
# 7027 : ut : ut
# 7028 : aduan : adu
# 7029 : trouble : trouble
# 7030 : penyelesaian : selesai
# 7031 : gigit : gigit
# 7032 : pengganti : ganti
# 7033 : world : world
# 7034 : worsted : worsted
# 7035 : ever : ever
# 7036 : jlsseharusnya : jlsseharusnya
# 7037 : disuruh : suruh
# 7038 : menangtpi : menangtpi
# 7039 : jelekjdinya : jelekjdinya
# 7040 : questnya : questnya
# 7041 : adilketika : adilketika
# 7042 : bermainsaya : bermainsaya
# 7043 : bawahsedangkan : bawahsedangkan
# 7044 : gamemendingan : gamemendingan
# 7045 : tidan : tidan
# 7046 : film : film
# 7047 : logoutafk : logoutafk
# 7048 : lokal : lokal
# 7049 : memamerkan : pamer
# 7050 : kebanggaan : bangga
# 7051 : berbedasalju : berbedasalju
# 7052 : samping : samping
# 7053 : hertod : hertod
# 7054 : kren : kren
# 7055 : trms : trms
# 7056 : woiii : woiii
# 7057 : lucky : lucky
# 7058 : diganti : ganti
# 7059 : penukaran : tukar
# 7060 : cristal : cristal
# 7061 : berulangkali : berulangkali
# 7062 : deserve : deserve
# 7063 : menautkan : taut
# 7064 : telegram : telegram
# 7065 : keseimbngan : keseimbngan
# 7066 : buggkadang : buggkadang
# 7067 : kluar : kluar
# 7068 : sendirijaringan : sendirijaringan
# 7069 : wifipaket : wifipaket
# 7070 : internal : internal
# 7071 : ulangpenyimpanan : ulangpenyimpanan
# 7072 : loginndari : loginndari
# 7073 : tadikluar : tadikluar
# 7074 : terusss : terusss
# 7075 : benermonton : benermonton
# 7076 : jaringanterkadang : jaringanterkadang
# 7077 : plksedang : plksedang
# 7078 : semuaini : semuaini
# 7079 : pesnidan : pesnidan
# 7080 : warngekill : warngekill
# 7081 : dibunuh : bunuh
# 7082 : kaku : kaku
# 7083 : luas : luas
# 7084 : kayk : kayk
# 7085 : lalama : lalama
# 7086 : meninggal : tinggal
# 7087 : sekor : kor
# 7088 : turuntolong : turuntolong
# 7089 : sklil : sklil
# 7090 : setarakan : tara
# 7091 : seimbangmusuhnya : seimbangmusuhnya
# 7092 : gelobal : gelobal
# 7093 : maintolong : maintolong
# 7094 : ngespin : ngespin
# 7095 : aspirian : aspirian
# 7096 : desainnya : desain
# 7097 : emass : emass
# 7098 : kreatif : kreatif
# 7099 : berfungsierror : berfungsierror
# 7100 : lahn : lahn
# 7101 : delly : delly
# 7102 : mengekstrak : ekstrak
# 7103 : startup : startup
# 7104 : berpuluhpuluh : berpuluhpuluh
# 7105 : ekstrak : ekstrak
# 7106 : nyolot : nyolot
# 7107 : tidakk : tidakk
# 7108 : tertata : tata
# 7109 : indeks : indeks
# 7110 : berasumsi : asumsi
# 7111 : dipelihara : pelihara
# 7112 : analognya : analog
# 7113 : gerakannya : gera
# 7114 : bertuliskan : tulis
# 7115 : handphone : handphone
# 7116 : asalasalan : asalasalan
# 7117 : pertandingam : pertandingam
# 7118 : banke : banke
# 7119 : ngeriset : ngeriset
# 7120 : muluh : muluh
# 7121 : rusakgame : rusakgame
# 7122 : patahpadahal : patahpadahal
# 7123 : hang : hang
# 7124 : lagu : lagu
# 7125 : defeat : defeat
# 7126 : matchmaker : matchmaker
# 7127 : berantakan : beranta
# 7128 : truusssmoonton : truusssmoonton
# 7129 : seoson : seoson
# 7130 : pig : pig
# 7131 : samasekali : samasekali
# 7132 : wi : wi
# 7133 : moontonsetelah : moontonsetelah
# 7134 : ode : ode
# 7135 : cepatfeedbacknya : cepatfeedbacknya
# 7136 : froblem : froblem
# 7137 : seprti : seprti
# 7138 : itumasa : itumasa
# 7139 : draksystem : draksystem
# 7140 : meneng : neng
# 7141 : gunadan : gunadan
# {'gamenya': 'gamenya', 'bagus': 'bagus', 'grafiknya': 'grafik', 'lumayan': 'lumayan', 'tolonglah': 'tolong', 'kasih': 'kasih', 'lawan': 'lawan', 'bot': 'bot', 'yg': 'yg', 'kuat': 'kuat', 'tks': 'tks', 'aja': 'aja', 'disitu': 'situ', 'for': 'for', 'moonton': 'moonton', 'tolong': 'tolong', 'perbaiki': 'baik', 'bug': 'bug', 'freeze': 'freeze', 'kadang': 'kadang', 'ngeselin': 'ngeselin', 'war': 'war', 'enakenak': 'enakenak', 'eh': 'eh', 'tibatiba': 'tibatiba', 'ngefreeze': 'ngefreeze', 'ga': 'ga', 'relog': 'relog', 'males': 'males', 'nunggu': 'nunggu', 'loading': 'loading', 'screen': 'screen', 'ny': 'ny', 'lamaa': 'lamaa', 'server': 'server', 'nya': 'nya', 'game': 'game', 'kalah': 'kalah', 'player': 'player', 'hp': 'hp', 'panas': 'panas', 'menang': 'menang', 'panasgame': 'panasgame', 'hero': 'hero', 'menghabisi': 'habis', 'tim': 'tim', 'bilang': 'bilang', 'main': 'main', 'jujur': 'jujur', 'adiltidak': 'adiltidak', 'bikin': 'bikin', 'buang': 'buang', 'bodoh': 'bodoh', 'menerusya': 'menerusya', 'hapus': 'hapus', 'online': 'online', 'pusing': 'pusing', 'serang': 'serang', 'lag': 'lag', 'abis': 'abis', 'update': 'update', 'dapet': 'dapet', 'dark': 'dark', 'system': 'system', 'keselnya': 'kesel', 'blacklist': 'blacklist', 'bisanya': 'bisa', 'ketemu': 'ketemu', 'trus': 'trus', 'setim': 'tim', 'emosi': 'emosi', 'cuman': 'cuman', 'gue': 'gue', 'lose': 'lose', 'streak': 'streak', 'epik': 'epik', 'bintang': 'bintang', 'gm': 'gm', 'dpt': 'dpt', 'sistem': 'sistem', 'musuhnya': 'musuh', 'pro': 'pro', 'bngt': 'bngt', 'wajar': 'wajar', 'capek': 'capek', 'sampe': 'sampe', 'lagiseribu': 'lagiseribu', 'tantangan': 'tantang', 'gw': 'gw', 'lewati': 'lewat', 'sih': 'sih', 'cokk': 'cokk', 'cape': 'cape', 'bgt': 'bgt', 'gua': 'gua', 'asli': 'asli', 'solo': 'solo', 'gila': 'gila', 'banget': 'banget', 'bener': 'bener', 'mulu': 'mulu', 'sumpah': 'sumpah', 'jujuran': 'jujuran', 'klo': 'klo', 'pemilihan': 'pilih', 'hok': 'hok', 'banding': 'banding', 'ml': 'ml', 'kecewa': 'kecewa', 'karna': 'karna', 'perubahan': 'ubah', 'dengar': 'dengar', 'suara': 'suara', 'ranked': 'ranked', 'bedain': 'bedain', 'hallo': 'hallo', 'kesekian': 'sekian', 'kali': 'kali', 'kalo': 'kalo', 'match': 'match', 'team': 'team', 'yng': 'yng', 'tau': 'tau', 'maen': 'maen', 'gak': 'gak', 'seneng': 'neng', 'x': 'x', 'masuk': 'masuk', 'akal': 'akal', 'dilaporin': 'dilaporin', 'dihukum': 'hukum', 'jng': 'jng', 'uninstall': 'uninstall', 'tukang': 'tukang', 'trolll': 'trolll', 'diperhatikan': 'perhati', 'keluhan': 'keluh', 'rank': 'rank', 'menemukan': 'temu', 'musuh': 'musuh', 'pangkatnya': 'pangkat', 'udah': 'udah', 'mencapai': 'capai', 'mitic': 'mitic', 'sasangkan': 'sasangkan', 'legend': 'legend', 'pastinya': 'pasti', 'diperbaiki': 'baik', 'mengganti': 'ganti', 'akun': 'akun', 'muncul': 'muncul', 'tulisan': 'tulis', 'jaringan': 'jaring', 'stabil': 'stabil', 'mohon': 'mohon', 'mencoba': 'coba', 'ulang': 'ulang', 'gagal': 'gagal', 'suruh': 'suruh', 'gara': 'gara', 'kebanyakan': 'banyak', 'tertinggi': 'tinggi', 'gwe': 'gwe', 'bilng': 'bilng', 'udh': 'udh', 'paham': 'paham', 'itemrotasimasak': 'itemrotasimasak', 'rnk': 'rnk', 'master': 'master', 'kesimpulan': 'simpul', 'ngasalgak': 'ngasalgak', 'ngimbangin': 'ngimbangin', 'jagosejago': 'jagosejago', 'apapun': 'apa', 'kasi': 'kasi', 'trol': 'trol', 'gk': 'gk', 'bkl': 'bkl', 'ngpain': 'ngpain', 'masukan': 'masuk', 'ajkasi': 'ajkasi', 'random': 'random', 'sesuai': 'sesuai', 'minimal': 'minimal', 'mainyg': 'mainyg', 'permainan': 'main', 'jago': 'jago', 'pilih': 'pilih', 'kasihgak': 'kasihgak', 'adi': 'adi', 'lalam': 'lalam', 'susah': 'susah', 'orang': 'orang', 'masi': 'mas', 'pilh': 'pilh', 'menag': 'menag', 'deluan': 'delu', 'tower': 'tower', 'hancurin': 'hancurin', 'mudah': 'mudah', 'giliran': 'gilir', 'nian': 'nian', 'ujung': 'ujung', 'gulang': 'gulang', 'reng': 'reng', 'nyo': 'nyo', 'idk': 'idk', 'temen': 'temen', 'sekolah': 'sekolah', 'ajak': 'ajak', 'mabar': 'mabar', 'gem': 'gem', 'ajing': 'ajing', 'buruk': 'buruk', 'anggota': 'anggota', 'feed ...
# ------------------------
#                                               content  score    Label  \
# 0   Gamenya bagus, grafiknya lumayan, tapi tolongl...      1  Negatif
# 1   for moonton tolong dong di perbaiki lagi bug f...      1  Negatif
# 2   Game ini jika mau kasih kalah player hp jadi p...      1  Negatif
# 3   Tiap abis update pasti dapet dark system dan k...      1  Negatif
# 4   bagus gamenya cuman gue lose streak dari epik ...      2  Negatif
# 5   Game apa sih ini cokk cape bgt gua asli buat p...      1  Negatif
# 6   Hallo moonton, ini untuk kesekian kali nya, ka...      2  Negatif
# 8   saya ada keluhan sedikit kenapa saya saat main...      1  Negatif
# 9   ada bug saat mengganti akun muncul tulisan jar...      1  Negatif
# 10  Rank tertinggi gwe mitic 29,,bisa di bilng udh...      2  Negatif
# 12  Permainan di kasi musuh yg jago yg sesuai lah ...      1  Negatif
# 13  Jujur lah saya dpt tim yang sangat amat buruk ...      1  Negatif
# 14  Untuk kedepannya mohon perbaiki masalah sinyal...      2  Negatif
# 15  Sudah sekian lama game ini masih saja ngeleg s...      1  Negatif
# 16  Game nya sudah bagus dari tampilan grafik dan ...      2  Negatif
# 18  Game nya menyenangkan cuma yang belum kecandua...      1  Negatif
# 19  Mobile legends untuk pengembang kalau nggak be...      1  Negatif
# 20  game sampah setiap main di kasih tim drak syst...      1  Negatif
# 21  masa gue donlot data ga bisa jalan jalan sih, ...      1  Negatif
# 22  Matchmakingnya tolong diperbaiki. Perbedaan ra...      1  Negatif
#
#                                            text_clean  \
# 0   gamenya bagus grafiknya lumayan tapi tolonglah...
# 1   for moonton tolong dong di perbaiki lagi bug f...
# 2   game ini jika mau kasih kalah player hp jadi p...
# 3   tiap abis update pasti dapet dark system dan k...
# 4   bagus gamenya cuman gue lose streak dari epik ...
# 5   game apa sih ini cokk cape bgt gua asli buat p...
# 6   hallo moonton ini untuk kesekian kali nya kalo...
# 8   saya ada keluhan sedikit kenapa saya saat main...
# 9   ada bug saat mengganti akun muncul tulisan jar...
# 10  rank tertinggi gwe mitic bisa di bilng udh pah...
# 12  permainan di kasi musuh yg jago yg sesuai lah ...
# 13  jujur lah saya dpt tim yang sangat amat buruk ...
# 14  untuk kedepannya mohon perbaiki masalah sinyal...
# 15  sudah sekian lama game ini masih saja ngeleg s...
# 16  game nya sudah bagus dari tampilan grafik dan ...
# 18  game nya menyenangkan cuma yang belum kecandua...
# 19  mobile legends untuk pengembang kalau nggak be...
# 20  game sampah setiap main di kasih tim drak syst...
# 21  masa gue donlot data ga bisa jalan jalan sih b...
# 22  matchmakingnya tolong diperbaiki perbedaan ran...
#
#                                         text_Stopword  \
# 0   gamenya bagus grafiknya lumayan tolonglah kasi...
# 1   for moonton tolong perbaiki bug freeze kadang ...
# 2   game kasih kalah player hp panas kasih player ...
# 3   abis update dapet dark system keselnya player ...
# 4   bagus gamenya cuman gue lose streak epik binta...
# 5   game sih cokk cape bgt gua asli player solo gi...
# 6   hallo moonton kesekian kali nya kalo match dap...
# 8   keluhan main rank menemukan musuh pangkatnya u...
# 9   bug mengganti akun muncul tulisan jaringan sta...
# 10  rank tertinggi gwe mitic bilng udh paham itemr...
# 12  permainan kasi musuh yg jago yg sesuai gua kal...
# 13  jujur dpt tim buruk kadang anggota tim feedeer...
# 14  kedepannya mohon perbaiki sinyaljaringan bange...
# 15  sekian game ngeleg bertempur jgn gituh nonton ...
# 16  game nya bagus tampilan grafik hero nya mantap...
# 18  game nya menyenangkan kecanduan deh emosi mont...
# 19  mobile legends pengembang nggak becus mengelol...
# 20  game sampah main kasih tim drak system cape gu...
# 21  gue donlot data ga jalan jalan sih beebrapa ud...
# 22  matchmakingnya tolong diperbaiki perbedaan ran...
#
#                                           text_tokens  \
# 0   [gamenya, bagus, grafiknya, lumayan, tolonglah...
# 1   [for, moonton, tolong, perbaiki, bug, freeze, ...
# 2   [game, kasih, kalah, player, hp, panas, kasih,...
# 3   [abis, update, dapet, dark, system, keselnya, ...
# 4   [bagus, gamenya, cuman, gue, lose, streak, epi...
# 5   [game, sih, cokk, cape, bgt, gua, asli, player...
# 6   [hallo, moonton, kesekian, kali, nya, kalo, ma...
# 8   [keluhan, main, rank, menemukan, musuh, pangka...
# 9   [bug, mengganti, akun, muncul, tulisan, jaring...
# 10  [rank, tertinggi, gwe, mitic, bilng, udh, paha...
# 12  [permainan, kasi, musuh, yg, jago, yg, sesuai,...
# 13  [jujur, dpt, tim, buruk, kadang, anggota, tim,...
# 14  [kedepannya, mohon, perbaiki, sinyaljaringan, ...
# 15  [sekian, game, ngeleg, bertempur, jgn, gituh, ...
# 16  [game, nya, bagus, tampilan, grafik, hero, nya...
# 18  [game, nya, menyenangkan, kecanduan, deh, emos...
# 19  [mobile, legends, pengembang, nggak, becus, me...
# 20  [game, sampah, main, kasih, tim, drak, system,...
# 21  [gue, donlot, data, ga, jalan, jalan, sih, bee...
# 22  [matchmakingnya, tolong, diperbaiki, perbedaan...
#
#                                        text_steamindo
# 0   gamenya bagus grafik lumayan tolong kasih lawa...
# 1   for moonton tolong baik bug freeze kadang nges...
# 2   game kasih kalah player hp panas kasih player ...
# 3   abis update dapet dark system kesel player yg ...
# 4   bagus gamenya cuman gue lose streak epik binta...
# 5   game sih cokk cape bgt gua asli player solo gi...
# 6   hallo moonton sekian kali nya kalo match dapet...
# 8   keluh main rank temu musuh pangkat udah capai ...
# 9   bug ganti akun muncul tulis jaring stabil jari...
# 10  rank tinggi gwe mitic bilng udh paham itemrota...
# 12  main kasi musuh yg jago yg sesuai gua kalah pi...
# 13  jujur dpt tim buruk kadang anggota tim feedeer...
# 14  depan mohon baik sinyaljaringan banget merah w...
# 15  sekian game ngeleg tempur jgn gituh nonton gw ...
# 16  game nya bagus tampil grafik hero nya mantap k...
# 18  game nya senang candu deh emosi montoon pusat ...
# 19  mobile legends kembang nggak becus kelola apli...
# 20  game sampah main kasih tim drak system cape gu...
# 21  gue donlot data ga jalan jalan sih beebrapa ud...
# 22  matchmakingnya tolong baik beda rank imbang ja...

# %% [markdown]
# #Data Clean Raw-Result

# %%
data_clean.to_excel('EXCEL Raw-Result Data MLBB.xlsx', index=False)
data_clean.to_csv('CSV Raw-Result Data MLBB.csv', index=False)

# %% [markdown]
# #Data Clean Clean-Result

# %%
data_clean_cln = data_clean[['text_steamindo', 'score', 'Label']]
data_clean_cln = data_clean_cln.rename(columns={'text_steamindo':'review'})
len(data_clean_cln)
# Out:
# 1789

# %%
data_clean_cln.to_csv('CSV Clean-Result Data MLBB.csv', index=False)
data_clean_cln.to_excel('EXCEL Clean-Result Data MLBB.xlsx', index=False)
