# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# #PUBG Mobile

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  34ff4c9f-bd29-4554-a652-3e1f1963ae69  Pengguna Google
# 1  e0f2bf54-5404-4678-a0d0-da0a8d153e55  Pengguna Google
# 2  2c23b298-46ed-4ef5-8d2d-2c3a5a6e57e9  Pengguna Google
# 3  6fce1800-fe7e-4601-9477-2fc23017e805  Pengguna Google
# 4  29bc2aff-9e61-48fd-9aa8-98bffe8f51b0  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Bug setelah update. 1 . Turun pesawat ga kebag...      2              3
# 1  Pubg setelah update bnyak aja masalahnya, sepe...      2              2
# ...

# %%
len(df_busu.index)
# Out:
# 10000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      2 2019-04-20 03:46:42
# 1  Pengguna Google      2 2020-09-08 11:23:56
# 2  Pengguna Google      1 2022-02-23 09:00:31
# 3  Pengguna Google      1 2020-03-04 23:20:09
# 4  Pengguna Google      1 2024-10-02 04:38:42
#
#                                              content
# 0  Bug setelah update. 1 . Turun pesawat ga kebag...
# 1  Pubg setelah update bnyak aja masalahnya, sepe...
# 2  Tidak ada masalah pada sinyal/pun device. Tapi...
# 3  Update file gajah terooos,tapi bug mic,sound m...
# 4  mohon untuk ini di perbaiki, update bulan sebe...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#             userName  score                  at  \
# 125  Pengguna Google      3 2024-10-02 15:32:46
# 829  Pengguna Google      1 2024-10-02 15:25:32
# 365  Pengguna Google      1 2024-10-02 15:10:46
# 254  Pengguna Google      1 2024-10-02 14:21:52
# 379  Pengguna Google      2 2024-10-02 14:19:46
#
#                                                content
# 125  Mengapa saya beri bintang 3 ,karena sering ter...
# 829  saya sering mengalami stuck loading pada saat ...
# 365  Pubg pubg kebnyakan update kalau ada musuh fra...
# 254  Setelah update download map saja tidak bisa ad...
# 379  Sering bug keluar sendiri udah ga wortid Untuk...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                content  score
# 125  Mengapa saya beri bintang 3 ,karena sering ter...      3
# 829  saya sering mengalami stuck loading pada saat ...      1
# 365  Pubg pubg kebnyakan update kalau ada musuh fra...      1
# 254  Setelah update download map saja tidak bisa ad...      1
# 379  Sering bug keluar sendiri udah ga wortid Untuk...      2

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head(50)
# Out:
#                                                 content  score    Label
# 125   Mengapa saya beri bintang 3 ,karena sering ter...      3     None
# 829   saya sering mengalami stuck loading pada saat ...      1  Negatif
# 365   Pubg pubg kebnyakan update kalau ada musuh fra...      1  Negatif
# 254   Setelah update download map saja tidak bisa ad...      1  Negatif
# 379   Sering bug keluar sendiri udah ga wortid Untuk...      2  Negatif
# 2117  Loadingnya lama dan gemnya bikin bingung saya ...      1  Negatif
# 1380  Tambahkan fitur kemana saja UC dihabiskan, UC ...      3     None
# 792   Kenapa saya tdk bisa login pubg. Saat ingin lo...      1  Negatif
# 127   Tolong notifikasinya jgn di kirim pas game sed...      4  Positif
# 6744  Saya sudah memainkan Pubg mulai awal 2016 smpa...      5  Positif
# 842   Aplikasi saya sering bermasalah saat login, ka...      1  Negatif
# 1430  Kenapa main metro royal ada player musuh belar...      5  Positif
# ...

# %%
my_df.to_csv('scrapped_data_pubgm.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/scrapped_data_pubgm.csv')
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Mengapa saya beri bintang 3 ,karena sering ter...      3      NaN
# 1   saya sering mengalami stuck loading pada saat ...      1  Negatif
# 2   Pubg pubg kebnyakan update kalau ada musuh fra...      1  Negatif
# 3   Setelah update download map saja tidak bisa ad...      1  Negatif
# 4   Sering bug keluar sendiri udah ga wortid Untuk...      2  Negatif
# 5   Loadingnya lama dan gemnya bikin bingung saya ...      1  Negatif
# 6   Tambahkan fitur kemana saja UC dihabiskan, UC ...      3      NaN
# 7   Kenapa saya tdk bisa login pubg. Saat ingin lo...      1  Negatif
# 8   Tolong notifikasinya jgn di kirim pas game sed...      4  Positif
# 9   Saya sudah memainkan Pubg mulai awal 2016 smpa...      5  Positif
# 10  Aplikasi saya sering bermasalah saat login, ka...      1  Negatif
# 11  Kenapa main metro royal ada player musuh belar...      5  Positif
# ...

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10000 non-null  object
#  1   score    10000 non-null  int64
#  2   Label    8391 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False   True
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 9995    False  False  False
# 9996    False  False  False
# 9997    False  False  False
# 9998    False  False  False
# 9999    False  False  False
#
# [10000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#               score
# count  10000.000000
# mean       2.539200
# std        1.546966
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max        5.000000

# %%
my_df.isnull().sum()
# Out:
# content       0
# score         0
# Label      1609
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 1   saya sering mengalami stuck loading pada saat ...      1  Negatif
# 2   Pubg pubg kebnyakan update kalau ada musuh fra...      1  Negatif
# 3   Setelah update download map saja tidak bisa ad...      1  Negatif
# 4   Sering bug keluar sendiri udah ga wortid Untuk...      2  Negatif
# 5   Loadingnya lama dan gemnya bikin bingung saya ...      1  Negatif
# 7   Kenapa saya tdk bisa login pubg. Saat ingin lo...      1  Negatif
# 8   Tolong notifikasinya jgn di kirim pas game sed...      4  Positif
# 9   Saya sudah memainkan Pubg mulai awal 2016 smpa...      5  Positif
# 10  Aplikasi saya sering bermasalah saat login, ka...      1  Negatif
# 11  Kenapa main metro royal ada player musuh belar...      5  Positif
# 12  Mohon developer game ini ditinggalkan lagi sep...      4  Positif
# 13  mohon untuk ini di perbaiki, update bulan sebe...      1  Negatif
# ...

# %%
my_df.to_csv('pubgm_preprocessing.csv', index=False)
