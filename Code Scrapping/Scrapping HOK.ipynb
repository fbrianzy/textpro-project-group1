# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape Rating Play Store - HOK

# %%
result, continuation_token = reviews(
    'com.levelinfinite.sgameGlobal',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId       userName  \
# 0  36384958-3fba-4fb1-bf5a-27108bd3d8c4      Rimaulana
# 1  dbf37950-88ff-4f03-b191-244cda31e216      Growol ID
# 2  0995e9ab-939b-43cc-95be-1695329e0858  Minecraft New
# 3  278128e4-d6d3-44f4-b676-2609d21997d6      Irfan Moh
# 4  da54f393-924c-48e2-936b-d4217b6847af    Musa Fikhin
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Dari gw sendiri gamenya udh cukup bagus mulai ...      4             14
# 1  [UPDATE] Sudah lancar kembali setelah update t...      5             61
# 2  Menurut pendapat saya game ini cukup bagus cum...      3             14
# ...

# %%
len(df_busu.index)
# Out:
# 2000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#         userName  score                  at  \
# 0      Rimaulana      4 2024-10-10 13:33:41
# 1      Growol ID      5 2024-10-11 08:53:09
# 2  Minecraft New      3 2024-10-10 04:55:13
# 3      Irfan Moh      3 2024-10-10 13:12:12
# 4    Musa Fikhin      1 2024-10-10 03:32:55
#
#                                              content
# 0  Dari gw sendiri gamenya udh cukup bagus mulai ...
# 1  [UPDATE] Sudah lancar kembali setelah update t...
# 2  Menurut pendapat saya game ini cukup bagus cum...
# 3  Kenapa sering suruh instal data yang di dalamn...
# 4  segi Game play bagus, grafik.. Tapi team selal...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#               userName  score                  at  \
# 488       Jepri Dandri      1 2024-11-06 16:07:04
# 1181      satria Rohan      1 2024-11-06 05:06:34
# 307     Sahrul Pratama      1 2024-11-03 01:58:54
# 1187     Selamet amrin      1 2024-11-03 01:47:46
# 485   Alfandi Alfandii      1 2024-11-01 06:50:11
#
#                                                 content
# 488   Emang sampah sistem game loe Tencent t43k koto...
# 1181  Saya sudah memainkan honor of Kings lebih dari...
# 307   Maching ngga seimbang , tiap main ranked selal...
# 1187  tolong lah di perbaiki buat hero sesuai karakt...
# 485   gamenya overal udah bagus sih,cuman yang harus...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                 content  score
# 488   Emang sampah sistem game loe Tencent t43k koto...      1
# 1181  Saya sudah memainkan honor of Kings lebih dari...      1
# 307   Maching ngga seimbang , tiap main ranked selal...      1
# 1187  tolong lah di perbaiki buat hero sesuai karakt...      1
# 485   gamenya overal udah bagus sih,cuman yang harus...      1

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head()
# Out:
#                                                 content  score    Label
# 488   Emang sampah sistem game loe Tencent t43k koto...      1  Negatif
# 1181  Saya sudah memainkan honor of Kings lebih dari...      1  Negatif
# 307   Maching ngga seimbang , tiap main ranked selal...      1  Negatif
# 1187  tolong lah di perbaiki buat hero sesuai karakt...      1  Negatif
# 485   gamenya overal udah bagus sih,cuman yang harus...      1  Negatif

# %%
my_df.to_csv('Scrapped-Data HOK.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/Scrapped-Data HOK.csv')
my_df.head()
# Out:
#                                              content  score    Label
# 0  Emang sampah sistem game loe Tencent t43k koto...      1  Negatif
# 1  Saya sudah memainkan honor of Kings lebih dari...      1  Negatif
# 2  Maching ngga seimbang , tiap main ranked selal...      1  Negatif
# 3  tolong lah di perbaiki buat hero sesuai karakt...      1  Negatif
# 4  gamenya overal udah bagus sih,cuman yang harus...      1  Negatif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2000 non-null   object
#  1   score    2000 non-null   int64
#  2   Label    1743 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 1995    False  False  False
# 1996    False  False  False
# 1997    False  False  False
# 1998    False  False  False
# 1999    False  False   True
#
# [2000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2000.000000
# mean      2.398000
# std       1.532243
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      257
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Emang sampah sistem game loe Tencent t43k koto...      1  Negatif
# 1   Saya sudah memainkan honor of Kings lebih dari...      1  Negatif
# 2   Maching ngga seimbang , tiap main ranked selal...      1  Negatif
# 3   tolong lah di perbaiki buat hero sesuai karakt...      1  Negatif
# 4   gamenya overal udah bagus sih,cuman yang harus...      1  Negatif
# 5   Untuk developer gamenya sudah bagus,dari segi ...      4  Positif
# 6   Untuk pihak Tencent secara teknis game sudah b...      4  Positif
# 7   Rusak game nya banyak bot. Mau naik rank aja s...      1  Negatif
# 8   Game haram yg pernah gua download, kirain baka...      1  Negatif
# 9   Jujur aja suka Ama game nya,tapi akhir akhir i...      1  Negatif
# 10  hei, pembuat game hok.tolong lah dikurangi dar...      1  Negatif
# 11  sekarang saya udh di rank grandmaster, dan mat...      5  Positif
# ...

# %%
my_df.to_csv('Scrapping-HOK.csv', index=False)
