# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape Rating Play Store - FF

# %%
result, continuation_token = reviews(
    'com.dts.freefireth',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId              userName  \
# 0  fb765ba9-cf47-440e-b4af-82cfd7d014b5  Maulana Okta saputra
# 1  0d8f0f64-7e21-44b8-b26b-acb2110a8a49       Hikaru Satoushi
# 2  952cc277-5719-49a4-9659-6ce584809f5c           Oga Septian
# 3  31b04ae5-fca8-4c59-bce6-4117fa56ea97             BA GAMING
# 4  fa8f04e7-bd00-47b0-a9db-a127f5ee8948             fata fata
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Game ini emang sangat bagus , dan game ini men...      3            425
# 1  Untuk davelooper mohon diperbaiki bug nya dong...      3            947
# 2  Kenapa liat skin musuh sekarang harus pake gra...      4             34
# 3  Dalam mode gun fight (Sniper). Tolong tombol d...      2           4919
# 4  Keluhan saya atau mungkin juga banyak di luar ...      2            473
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              1.106.1 2024-11-01 12:57:32         None       NaT    1.106.1
# 1              1.106.1 2024-10-19 14:14:59         None       NaT    1.106.1
# 2              1.107.0 2024-11-07 11:58:23         None       NaT    1.107.0
# 3              1.106.1 2024-10-28 10:30:16         None       NaT    1.106.1
# 4              1.106.1 2024-10-15 22:20:41         None       NaT    1.106.1

# %%
len(df_busu.index)
# Out:
# 2000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#                userName  score                  at  \
# 0  Maulana Okta saputra      3 2024-11-01 12:57:32
# 1       Hikaru Satoushi      3 2024-10-19 14:14:59
# 2           Oga Septian      4 2024-11-07 11:58:23
# 3             BA GAMING      2 2024-10-28 10:30:16
# 4             fata fata      2 2024-10-15 22:20:41
#
#                                              content
# 0  Game ini emang sangat bagus , dan game ini men...
# 1  Untuk davelooper mohon diperbaiki bug nya dong...
# 2  Kenapa liat skin musuh sekarang harus pake gra...
# 3  Dalam mode gun fight (Sniper). Tolong tombol d...
# 4  Keluhan saya atau mungkin juga banyak di luar ...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#                userName  score                  at  \
# 501     Muhammad Zubair      1 2024-11-08 17:30:52
# 1299   Erpan Adi yahyaa      4 2024-11-08 16:04:26
# 250        Budi Priyono      3 2024-11-08 15:12:07
# 25    reyfaldy ramadhan      1 2024-11-08 14:39:11
# 416      Selberius Jusi      2 2024-11-08 13:56:46
#
#                                                 content
# 501   Game nya seru tpi banyak yg rusak gak kayak dl...
# 1299  terkadang kalo deket SMA musuh ngeleg jaringan...
# 250   Maaf garena kasih bintang 3, soalnya saya seba...
# 25    Game gj,game gk jelas,suka bug darah udh kena ...
# 416   Game bagus, tapi banyak masalah nya, terutama ...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                 content  score
# 501   Game nya seru tpi banyak yg rusak gak kayak dl...      1
# 1299  terkadang kalo deket SMA musuh ngeleg jaringan...      4
# 250   Maaf garena kasih bintang 3, soalnya saya seba...      3
# 25    Game gj,game gk jelas,suka bug darah udh kena ...      1
# 416   Game bagus, tapi banyak masalah nya, terutama ...      2

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head()
# Out:
#                                                 content  score    Label
# 501   Game nya seru tpi banyak yg rusak gak kayak dl...      1  Negatif
# 1299  terkadang kalo deket SMA musuh ngeleg jaringan...      4  Positif
# 250   Maaf garena kasih bintang 3, soalnya saya seba...      3     None
# 25    Game gj,game gk jelas,suka bug darah udh kena ...      1  Negatif
# 416   Game bagus, tapi banyak masalah nya, terutama ...      2  Negatif

# %%
my_df.to_csv('Scrapped-Data FF.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/Scrapped-Data FF.csv')
my_df.head()
# Out:
#                                              content  score    Label
# 0  Game nya seru tpi banyak yg rusak gak kayak dl...      1  Negatif
# 1  terkadang kalo deket SMA musuh ngeleg jaringan...      4  Positif
# 2  Maaf garena kasih bintang 3, soalnya saya seba...      3      NaN
# 3  Game gj,game gk jelas,suka bug darah udh kena ...      1  Negatif
# 4  Game bagus, tapi banyak masalah nya, terutama ...      2  Negatif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2000 non-null   object
#  1   score    2000 non-null   int64
#  2   Label    1741 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False  False
# 1       False  False  False
# 2       False  False   True
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 1995    False  False  False
# 1996    False  False  False
# 1997    False  False  False
# 1998    False  False  False
# 1999    False  False  False
#
# [2000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2000.000000
# mean      2.808500
# std       1.648996
# min       1.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      259
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Game nya seru tpi banyak yg rusak gak kayak dl...      1  Negatif
# 1   terkadang kalo deket SMA musuh ngeleg jaringan...      4  Positif
# 3   Game gj,game gk jelas,suka bug darah udh kena ...      1  Negatif
# 4   Game bagus, tapi banyak masalah nya, terutama ...      2  Negatif
# 5   Garena curang,, signal nya di cut, agar musuh ...      1  Negatif
# 6   apalah garena kami maen br rank kok mode nya c...      1  Negatif
# 7   game paling ga jelas,banyak cheater berkeliara...      1  Negatif
# 9   Game apa ini lawannya kayak pro player jago se...      2  Negatif
# 10  Gloo Nova] Bermuda kini penuh dengan Gloo! Gun...      5  Positif
# 11  Game nya bagus, tapi knp pas login selalu di k...      2  Negatif
# 12  Garena tolong la kasih tim yg benar di cs rank...      1  Negatif
# 13  Wajar player banyak pensi, semakin lama semaki...      1  Negatif
# 14  FF SEKARANG GK SERU!!! 1.playernya toxic 2.bug...      1  Negatif
# 15  game nya bagusss banget meskipun aku sama teme...      5  Positif
# 16  Ini game yang sangat bagus super duper bagus s...      5  Positif
# 17  Ga usah di tanya lagi udah game burik ga ada p...      2  Negatif
# 18  Tolong di perbaiki aplikasi mendonload data se...      1  Negatif
# 19  Game iniiiiiiii sangatttttt susah banget. Kena...      1  Negatif
# 20  Cara mudah membuat foto bugil gadis cantik ini...      5  Positif
# 21  Tolong Tambahkan Mode Outlaw lagi, Itu Mode Ga...      4  Positif
# 22  karena saya sangat suka gem ini cuman coba kas...      5  Positif
# 23  Tolong di uba lagi demegnya soalnya sering geb...      5  Positif
# 24  Jangan di download ini permainan curang masa m...      1  Negatif
# 25  Saya tidak puas dengan game update yg sekarang...      1  Negatif
# 26  Min tambahkan settingan rosulusi per bit layar...      1  Negatif
# 27  Gua ada keluhan. Kenapa pas udh tertutup dindi...      2  Negatif
# 28  game masih banyak citer,kalo bisa next update ...      1  Negatif
# 29  Sinyal nya yg suka lag gak karuan.... Udah pai...      1  Negatif
# 30  walaupun 8 bit namun game ini seru dan bagus g...      5  Positif
# 31  Event absen harian dan crystal royale reload/l...      1  Negatif
# 32  Gem apa lah hampir tiap hari Update terus, ngg...      1  Negatif
# 33  Tolong perbaiki bug jaringan pada gamenya.siny...      1  Negatif
# 34  Kenapa liat skin musuh sekarang harus pake gra...      4  Positif
# 35  1).auto loot udh di mode cepat tapi tetep lele...      1  Negatif
# 36  Saya agak sedikit kecewa dengan game ini, dika...      2  Negatif
# 37  udh seru bgt sih, tapi menurut saya jangan sel...      4  Positif
# 38  Gem stresssss udh di blmg ga modif file atauu ...      1  Negatif
# 39  Percuma map random tapi dapetnya itu itu aja, ...      1  Negatif
# 40  Game ini seru tetapi kenapa setiap naik rank d...      1  Negatif
# 41  Masalah ram diatasi tapi bug jaringan sama bug...      1  Negatif
# 42  Akun saya sudah ngabisin banyak uang buat top ...      1  Negatif
# 43  Tolong dibenerin disini masih ada banyak bug l...      2  Negatif
# 44  Game selalu di update tadi game' play kek samp...      1  Negatif
# 45  Permainan Free Fire memang seru aku tidak bisa...      5  Positif
# 46  Game sangat bagus aku suka game nya awalnya si...      5  Positif
# 47  Woi Garena saya cuma mau ngingetin gem lu ini ...      1  Negatif
# 48  seru bgt permainan nya asik buat Mabar tapi su...      4  Positif
# 49  Game ya kurang bagus di rank atas musuhnya jag...      1  Negatif
# 50  game ini seru bgt bisa ganti foto bisa ganti k...      5  Positif
# 51  Game mantap tapi tolong kembalikan free fire y...      4  Positif

# %%
my_df.to_csv('Scrapping-FF.csv', index=False)
