# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape Rating Play Store - PUBGM

# %%
result, continuation_token = reviews(
    'com.tencent.ig',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  34ff4c9f-bd29-4554-a652-3e1f1963ae69  Pengguna Google
# 1  e0f2bf54-5404-4678-a0d0-da0a8d153e55  Fauzi Hardianto
# 2  2c23b298-46ed-4ef5-8d2d-2c3a5a6e57e9      iza .freeze
# 3  6fce1800-fe7e-4601-9477-2fc23017e805  Pengguna Google
# 4  db4e9f2e-53bb-4d47-ae32-31129172a9bf     SilverBoy 26
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Bug setelah update. 1 . Turun pesawat ga kebag...      2              3
# 1  Pubg setelah update bnyak aja masalahnya, sepe...      2              2
# 2  Tidak ada masalah pada sinyal/pun device. Tapi...      1              3
# 3  Update file gajah terooos,tapi bug mic,sound m...      1              0
# 4  entah device yang bermasalah, tapi saya merasa...      3              1
#
#   reviewCreatedVersion                  at  \
# 0               0.12.0 2019-04-20 03:46:42
# 1               0.13.0 2020-09-08 11:23:56
# 2                1.8.0 2022-02-23 09:00:31
# 3               0.16.0 2020-03-04 23:20:09
# 4                3.4.0 2024-11-08 14:02:17
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1  Hai, kami menyesal mendengar Anda mengalami ba... 2020-09-10 01:35:53
# 2  Halo iza, terima kasih atas tanggapannya menge... 2022-02-24 14:47:03
# 3                                               None                 NaT
# 4  Halo, pemain!\nJika perangkat Anda ada fungsi ... 2024-11-09 01:20:59
#
#   appVersion
# 0     0.12.0
# 1     0.13.0
# 2      1.8.0
# 3     0.16.0
# 4      3.4.0

# %%
len(df_busu.index)
# Out:
# 2000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      2 2019-04-20 03:46:42
# 1  Fauzi Hardianto      2 2020-09-08 11:23:56
# 2      iza .freeze      1 2022-02-23 09:00:31
# 3  Pengguna Google      1 2020-03-04 23:20:09
# 4     SilverBoy 26      3 2024-11-08 14:02:17
#
#                                              content
# 0  Bug setelah update. 1 . Turun pesawat ga kebag...
# 1  Pubg setelah update bnyak aja masalahnya, sepe...
# 2  Tidak ada masalah pada sinyal/pun device. Tapi...
# 3  Update file gajah terooos,tapi bug mic,sound m...
# 4  entah device yang bermasalah, tapi saya merasa...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#                userName  score                  at  \
# 833     Pengguna Google      2 2024-11-08 18:42:13
# 639   Risal Nagperantau      2 2024-11-08 15:53:42
# 1587       yasir saiban      1 2024-11-08 15:38:46
# 968     Supreme Suhendi      1 2024-11-08 14:46:06
# 155          Ogik Putra      1 2024-11-08 14:02:24
#
#                                                 content
# 833   tolong dong... ko kalo log in pake jaringan wi...
# 639   PUBG MOBILE sekarang sudah sepi, masuk match m...
# 1587              Server selalu bermasalah ketika login
# 968   Games terlalu berat, sering mati hp pas nembak...
# 155   Gyroscope pas diarahin ke bawan pelan malah na...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                 content  score
# 833   tolong dong... ko kalo log in pake jaringan wi...      2
# 639   PUBG MOBILE sekarang sudah sepi, masuk match m...      2
# 1587              Server selalu bermasalah ketika login      1
# 968   Games terlalu berat, sering mati hp pas nembak...      1
# 155   Gyroscope pas diarahin ke bawan pelan malah na...      1

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head()
# Out:
#                                                 content  score    Label
# 833   tolong dong... ko kalo log in pake jaringan wi...      2  Negatif
# 639   PUBG MOBILE sekarang sudah sepi, masuk match m...      2  Negatif
# 1587              Server selalu bermasalah ketika login      1  Negatif
# 968   Games terlalu berat, sering mati hp pas nembak...      1  Negatif
# 155   Gyroscope pas diarahin ke bawan pelan malah na...      1  Negatif

# %%
my_df.to_csv('Scrapped-Data PUBGM.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/Scrapped-Data PUBGM.csv')
my_df.head()
# Out:
#                                              content  score    Label
# 0  tolong dong... ko kalo log in pake jaringan wi...      2  Negatif
# 1  PUBG MOBILE sekarang sudah sepi, masuk match m...      2  Negatif
# 2              Server selalu bermasalah ketika login      1  Negatif
# 3  Games terlalu berat, sering mati hp pas nembak...      1  Negatif
# 4  Gyroscope pas diarahin ke bawan pelan malah na...      1  Negatif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2000 non-null   object
#  1   score    2000 non-null   int64
#  2   Label    1729 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 1995    False  False  False
# 1996    False  False  False
# 1997    False  False  False
# 1998    False  False  False
# 1999    False  False  False
#
# [2000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2000.000000
# mean      2.676000
# std       1.635041
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      271
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   tolong dong... ko kalo log in pake jaringan wi...      2  Negatif
# 1   PUBG MOBILE sekarang sudah sepi, masuk match m...      2  Negatif
# 2               Server selalu bermasalah ketika login      1  Negatif
# 3   Games terlalu berat, sering mati hp pas nembak...      1  Negatif
# 4   Gyroscope pas diarahin ke bawan pelan malah na...      1  Negatif
# 6   Ini game paling bagus menurut saya cuma sayang...      4  Positif
# 7   Dulu masalah frame dah teratasi skrg masalah b...      2  Negatif
# 10  Dari tahun 2021 sampai sekarang akun masih bis...      5  Positif
# 11  Pubg game haram. Masa gw login trus ndwonload ...      1  Negatif
# 12  Bangsd bug jalan pelan bener asu update trus b...      1  Negatif
# 13  Developer, aku mau permintaan nanti setelah up...      5  Positif
# 14  Coba pubg bisa offline sama kayak game yang la...      5  Positif
# 15  Dear PUBG Mobile. Teruntuk Keamanan PUBG yg te...      5  Positif
# 16  hahaha dapat musuh nya sulit sekali sedangkan ...      1  Negatif
# 17  game nya seru tapi game nya juga sangat berat,...      2  Negatif
# 18  Kenapa ketika saya main menggunakan data selul...      4  Positif
# 19  Woi pubg udah lah ngeframe padahal game lain l...      1  Negatif
# 20  Lagi main game bug kendala tidak bisa setabil ...      1  Negatif
# 21  Rumah terlalu buram tak bisa masuk cuman playe...      1  Negatif
# 22  game semakin update semakin aneh, pesawat temp...      1  Negatif
# 23  Main udh lama mau event nya gimana juga ttep m...      1  Negatif
# 24  Akhir2 ne kok sering sekali server tidak meres...      5  Positif
# 25  Game terlalu berat Tolong di perbaiki agar tid...      1  Negatif
# 26  Memory tambah besar. Main kadang ngelag2. Tida...      2  Negatif
# 28  Ini mau di perbaiki apa mau di rusak, masa ban...      1  Negatif
# 29  Krafton please no more fix the problems. Game ...      1  Negatif
# 30  Emang top lah ini,,,,tapi inget kenangan pas j...      5  Positif
# 31  Ku alihkan dunia ku dari judol ,yg meracuni ku...      5  Positif
# 32  Jelek bangetttt, kasi temen nya botttt. Minima...      1  Negatif
# 33  Kalo di tembaki cepet matinya , terus mau ngin...      4  Positif
# 34  Sangat baik, buat hiburan melepas penat habis ...      5  Positif
# 35  yg punya pubg ini gjmana sih, belum selesai pe...      1  Negatif
# 36  Sorry melenceng kesini sebab tidak bisa kasih ...      1  Negatif
# 37  Apalah layar gua sering tiba tiba ngestuck ga ...      1  Negatif
# 38  Ga terasa udh 5 tahun main PUBG gem yang sanga...      5  Positif
# 39  Sering mati disaat berlangsung nya game,,,pada...      2  Negatif
# 40  Hallo pubg mobile kasih aku lawan yang BOT aja...      5  Positif
# 43  kadang ada pemain yg jaringan na kurang bagus,...      1  Negatif
# 44    Game ini bagus banget grafik nya juga realities      5  Positif
# 45  Ngebug parah njirrrr.... G ada step tiba2 musu...      1  Negatif
# 47  Game sangat bagus dg taktik bermain dan skil p...      5  Positif
# 48  Game jelek ngelek dikit seribu bug yg keluar,k...      2  Negatif
# 49  Setelah saya update kok gak bisa masuk lagi ke...      4  Positif
# 51  kebanyakan update login fb aja susah muter² mu...      1  Negatif
# 52  Permainan sangat bagus dan senang kami main.cu...      5  Positif
# 54  Pugb sering error. Server tidak merespon. Ada ...      2  Negatif
# 55  kemaren gua report cheater yg jelas2 gua ada f...      1  Negatif
# 56  tolong kembalikan pubg mobile seperti dulu tan...      5  Positif
# 57  Game nya ngebug ga bisa login ke dalam gamenya...      1  Negatif
# 58  Good castle nya bisa di perdekat lagi , ga cum...      5  Positif

# %%
my_df.to_csv('Scrapping-PUBGM.csv', index=False)
