# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape Rating Play Store - MLBB

# %%
result, continuation_token = reviews(
    'com.mobile.legends',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=2000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  42a1c7f3-55e1-4a1e-a045-172de6cf1b16      Irfan Irfan
# 1  5023d824-0535-4b43-ba0d-eea17372389e             Rian
# 2  847f8fb1-aa9a-4aa4-a69b-66bdb439a60d    Julius Kaisar
# 3  c2b7ae88-d49d-4c25-a190-037a1be6096f            クンアサヒ
# 4  0cbc253c-5041-43ec-b0ad-d6effc42dd82  Ferdinan Markos
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Semakin hari semakin jelek. Gamenya pelit, ter...      1           1391
# 1  Bintang 1 karena apa ya betul bug sudah meraja...      1            185
# ...

# %%
len(df_busu.index)
# Out:
# 2000

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0      Irfan Irfan      1 2024-11-07 09:43:36
# 1             Rian      1 2024-11-07 08:41:28
# 2    Julius Kaisar      1 2024-11-07 12:57:31
# 3            クンアサヒ      1 2024-11-07 03:10:59
# 4  Ferdinan Markos      4 2024-11-08 04:08:45
#
#                                              content
# 0  Semakin hari semakin jelek. Gamenya pelit, ter...
# 1  Bintang 1 karena apa ya betul bug sudah meraja...
# 2  Hanya sedikit saran untuk perubahan dan semoga...
# 3  Game nya sangat mengasikan akan tetapi entah d...
# 4  udh beberapa reset season ini ntah knp sulit s...

# %%
new_df = df_busu[['userName', 'score', 'at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#                 userName  score                  at  \
# 1057           Elvionita      5 2024-11-08 18:13:05
# 56             Rio Denka      1 2024-11-08 18:02:56
# 7            Ataka Risqi      2 2024-11-08 18:00:36
# 1098  Malik Alfaqo akbar      1 2024-11-08 17:39:14
# 1862            Vivo Yo2      2 2024-11-08 17:39:08
#
#                                                 content
# 1057  Saya udah 10 tahun main ml TPI sekarang kecewa...
# 56    Kak admin yg baik hati dan tidak sombong.........
# 7     makin lama MLBB makin bikin emosi. jasingan pi...
# 1098  Setelah update jadi NGEFREEZ tidak bisa berger...
# 1862  Jujur aku kecewa kepada moonton karna sudah la...

# %%
my_df = sorted_df[['userName', 'score', 'at', 'content']]

# %%
my_df = my_df[['content', 'score']]

# %%
my_df.head()
# Out:
#                                                 content  score
# 1057  Saya udah 10 tahun main ml TPI sekarang kecewa...      5
# 56    Kak admin yg baik hati dan tidak sombong.........      1
# 7     makin lama MLBB makin bikin emosi. jasingan pi...      2
# 1098  Setelah update jadi NGEFREEZ tidak bisa berger...      1
# 1862  Jujur aku kecewa kepada moonton karna sudah la...      2

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4:
    return 'Positif'
  elif score == 5:
    return 'Positif'

my_df['Label'] = my_df['score'].apply(pelabelan)
my_df.head()
# Out:
#                                                 content  score    Label
# 1057  Saya udah 10 tahun main ml TPI sekarang kecewa...      5  Positif
# 56    Kak admin yg baik hati dan tidak sombong.........      1  Negatif
# 7     makin lama MLBB makin bikin emosi. jasingan pi...      2  Negatif
# 1098  Setelah update jadi NGEFREEZ tidak bisa berger...      1  Negatif
# 1862  Jujur aku kecewa kepada moonton karna sudah la...      2  Negatif

# %%
my_df.to_csv('Scrapped-Data MLBB.csv', index=False)

# %%
pd.set_option('display.max_column', None)
my_df = pd.read_csv('/content/Scrapped-Data MLBB.csv')
my_df.head()
# Out:
#                                              content  score    Label
# 0  Saya udah 10 tahun main ml TPI sekarang kecewa...      5  Positif
# 1  Kak admin yg baik hati dan tidak sombong.........      1  Negatif
# 2  makin lama MLBB makin bikin emosi. jasingan pi...      2  Negatif
# 3  Setelah update jadi NGEFREEZ tidak bisa berger...      1  Negatif
# 4  Jujur aku kecewa kepada moonton karna sudah la...      2  Negatif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2000 non-null   object
#  1   score    2000 non-null   int64
#  2   Label    1809 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
my_df.isna()
# Out:
#       content  score  Label
# 0       False  False  False
# 1       False  False  False
# 2       False  False  False
# 3       False  False  False
# 4       False  False  False
# ...       ...    ...    ...
# 1995    False  False  False
# 1996    False  False  False
# 1997    False  False  False
# 1998    False  False  False
# 1999    False  False   True
#
# [2000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  2000.000000
# mean      1.963500
# std       1.399338
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       3.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      191
# dtype: int64

# %%
my_df.dropna(subset=['Label'], inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Saya udah 10 tahun main ml TPI sekarang kecewa...      5  Positif
# 1   Kak admin yg baik hati dan tidak sombong.........      1  Negatif
# 2   makin lama MLBB makin bikin emosi. jasingan pi...      2  Negatif
# 3   Setelah update jadi NGEFREEZ tidak bisa berger...      1  Negatif
# 4   Jujur aku kecewa kepada moonton karna sudah la...      2  Negatif
# 5   Game lagendaris awet sampe 10 tahun.walau bany...      5  Positif
# 6   game ga ngotak yg baru download di satuin sma ...      1  Negatif
# 8   gila ini game, di kasih tim tidak jelas, dapat...      1  Negatif
# 9   Kalo buat gm yang bener bang ,jangan yang gak ...      5  Positif
# 11  tolong terkhusus buat moonton,masa iya dari wa...      1  Negatif
# 13  Pusat bermain Meta Mobile Legends sendiri adal...      5  Positif
# 14  Bagi saya aplikasi nya bagus tapiiii masak law...      2  Negatif
# ...

# %%
my_df.to_csv('Scrapping-MLBB.csv', index=False)
